# %% [markdown]
# <a href="https://colab.research.google.com/github/sgevatschnaider/IA-Teoria-Practica/blob/main/notebooks/Estructura_de_datos_tupla.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import display, HTML

# ==============================================================================
# 1. PLANTILLA HTML PARA TUPLAS
# ==============================================================================
html_template_tupla = """
<!DOCTYPE html>
<html lang="es">
<head>
  <!-- El head y el style son idénticos al original, solo cambia el título -->
  <meta charset="UTF-8">
  <title>Guía Interactiva de Tuplas en Python</title>
  <link href="https://fonts.googleapis.com/css2?family=Inter:wght@300;400;500;600;700;800&family=JetBrains+Mono:wght@400;500&display=swap" rel="stylesheet">
  <link href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.4.0/css/all.min.css" rel="stylesheet">
  <style>
    :root {{
      --bg-primary: #1a1a2e; --bg-secondary: rgba(27, 40, 69, 0.85); --bg-tertiary: rgba(45, 55, 72, 0.7);
      --text-primary: #e0e0e0; --text-secondary: #a0aec0; --accent-primary: #4eacfa; --accent-secondary: #c471ed;
      --accent-gradient: linear-gradient(135deg, var(--accent-primary) 0%, var(--accent-secondary) 100%);
      --border-color: rgba(255, 255, 255, 0.15); --shadow-card: 0 15px 35px rgba(0, 0, 0, 0.2);
      --border-radius: 15px; --transition: all 0.4s cubic-bezier(0.25, 0.8, 0.25, 1);
    }}
    * {{ margin: 0; padding: 0; box-sizing: border-box; }}
    html {{ scroll-behavior: smooth; }}
    body {{ font-family: 'Inter', sans-serif; line-height: 1.8; background-color: var(--bg-primary); color: var(--text-primary); }}
    .container {{ max-width: 1000px; margin: 0 auto; padding: 2rem; }}
    .header {{ text-align: center; margin-bottom: 3rem; }}
    .main-title {{ font-size: 3.5rem; font-weight: 800; background: var(--accent-gradient); -webkit-background-clip: text; color: transparent; background-clip: text; margin-bottom: 1rem; }}
    .subtitle {{ font-size: 1.3rem; color: var(--text-secondary); font-weight: 400; max-width: 800px; margin: auto; }}
    .lesson-container {{ display: flex; flex-direction: column; gap: 1.5rem; }}
    .topic-card {{ background: var(--bg-secondary); backdrop-filter: blur(10px); border-radius: var(--border-radius); box-shadow: var(--shadow-card); border: 1px solid var(--border-color); overflow: hidden; transition: var(--transition); }}
    .topic-header {{ cursor: pointer; padding: 1.5rem 2rem; display: flex; justify-content: space-between; align-items: center; }}
    .topic-title {{ font-size: 1.3rem; font-weight: 600; color: var(--text-primary); }}
    .expand-icon {{ font-size: 1.2rem; color: var(--text-secondary); transition: var(--transition); }}
    .topic-card.open .expand-icon {{ transform: rotate(180deg); }}
    .topic-content {{ max-height: 0; overflow: hidden; transition: max-height 1s ease-in-out, padding 1s ease-in-out; background: var(--bg-tertiary); }}
    .topic-card.open .topic-content {{ max-height: 5000px; padding: 1.5rem 2rem; border-top: 1px solid var(--border-color); }}
    .topic-content h3 {{ font-size: 1.2rem; color: var(--accent-primary); margin: 1.5rem 0 1rem 0; padding-bottom: 0.5rem; border-bottom: 2px solid var(--accent-secondary); }}
    .topic-content h3:first-child {{ margin-top: 0; }}
    .topic-content p, .topic-content li {{ margin-bottom: 1rem; color: var(--text-secondary); line-height: 1.7; }}
    .topic-content ul {{ padding-left: 20px; }}
    .topic-content strong {{ color: #ffffff; font-weight: 600; }}
    pre, .diagram {{ background: #0f172a; padding: 1.2rem; border-radius: 10px; border: 1px solid var(--border-color); overflow-x: auto; margin: 1.5rem 0; font-family: 'JetBrains Mono', monospace; font-size: 0.9em; color: #cbd5e1; white-space: pre-wrap; word-wrap: break-word; }}
    .code-output {{ background: #1e293b; color: #e2e8f0; font-family: 'JetBrains Mono', monospace; padding: 1rem; border-radius: 0 0 10px 10px; margin-top: -1.5rem; border: 1px solid var(--border-color); border-top:none; white-space: pre; }}
    .tip-box {{ background: rgba(78, 172, 250, 0.1); border-left: 4px solid var(--accent-primary); border-radius: 8px; padding: 1rem; margin: 1.5rem 0; }}
    .tip-box::before {{ content: '💡 Pythonic Tip: '; font-weight: bold; color: var(--accent-primary);}}
  </style>
</head>
<body>
  <div class="container">
    <header class="header">
      <h1 class="main-title">Guía Interactiva de Tuplas en Python</h1>
      <p class="subtitle">Una inmersión profunda en la estructura de datos inmutable por excelencia de Python. Descubre por qué su "limitación" es en realidad su mayor fortaleza.</p>
    </header>
    <div class="lesson-container">
        <div class="topic-card open">
            <div class="topic-header"><span class="topic-title">Parte 1: ¿Qué es una Tupla y Cómo se Crea?</span><i class="fas fa-chevron-down expand-icon"></i></div>
            <div class="topic-content">
                <p>La tupla es la "prima" inmutable de la lista. Es una colección que comparte dos características con las listas pero tiene una diferencia fundamental:</p>
                <ul><li><strong>Ordenada:</strong> Los elementos mantienen el orden en que fueron añadidos.</li><li><strong>Inmutable:</strong> ¡No puedes cambiar su contenido! Una vez creada, no puedes añadir, eliminar o modificar elementos.</li><li><strong>Heterogénea:</strong> Puede contener elementos de diferentes tipos (números, strings, otras tuplas, etc.).</li></ul>
                <h3>Formas de Crear una Tupla</h3><p>Puedes crear una tupla usando paréntesis <code>()</code> o con el constructor <code>tuple()</code>.</p>
                <div class="tip-box">¡Cuidado con las tuplas de un solo elemento! Para que Python no lo confunda con una simple expresión matemática entre paréntesis, debes añadir una coma al final: <code>(1,)</code>.</div>
                <pre># Creación con literales ()\ntupla_vacia = ()\ntupla_con_elementos = (1, "hola", 3.14, True)\n\n# ¡Caso especial! Tupla de un solo elemento\ntupla_un_elemento = ("solitario",)\n\n# Creación con el constructor tuple()\ntupla_desde_iterable = tuple("python")</pre>
                <div class="code-output">{output_tupla_p1_creacion}</div>
            </div>
        </div>
        <div class="topic-card">
            <div class="topic-header"><span class="topic-title">Parte 2: Acceso a Elementos (Indexing y Slicing)</span><i class="fas fa-chevron-down expand-icon"></i></div>
            <div class="topic-content">
                <p>El acceso a los elementos de una tupla es <strong>exactamente igual</strong> que en una lista. Puedes usar índices (empezando en cero) y slicing para obtener sub-tuplas.</p>
                <ul><li><strong>Indexing:</strong> <code>tupla[0]</code> para el primer elemento, <code>tupla[-1]</code> para el último.</li><li><strong>Slicing:</strong> <code>tupla[inicio:fin:paso]</code> para obtener una nueva tupla con una porción de la original.</li></ul>
                <pre>elementos = ('P', 'y', 't', 'h', 'o', 'n')\n# Indexing\nprimer_elemento = elementos[0]\nultimo_elemento = elementos[-1]\n# Slicing\nslice_basico = elementos[1:4]\ntupla_invertida = elementos[::-1]</pre>
                <div class="code-output">{output_tupla_p2_acceso}</div>
            </div>
        </div>
        <div class="topic-card">
            <div class="topic-header"><span class="topic-title">Parte 3: El Poder de la Inmutabilidad</span><i class="fas fa-chevron-down expand-icon"></i></div>
            <div class="topic-content">
                <p>Aquí reside la gran diferencia con las listas. Intentar modificar una tupla después de su creación resultará en un error. Esto no es una desventaja, sino una característica de diseño que garantiza la <strong>integridad de los datos</strong>.</p>
                <h3>Intentando lo Imposible</h3><p>Observa lo que pasa si intentamos asignar un nuevo valor a un índice o usar métodos como <code>.append()</code> (que no existe en las tuplas).</p>
                <pre>coordenadas = (10, 20)\n# Intentar cambiar un elemento\ncoordenadas[0] = 15  # Esto lanzará un TypeError</pre>
                <div class="code-output">{output_tupla_p3_inmutabilidad}</div>
                <h3>¿Cómo "modificar" una tupla entonces?</h3><p>No la modificas. Creas una <strong>nueva tupla</strong> a partir de las existentes, usualmente mediante concatenación (<code>+</code>).</p>
                <pre>punto_2d = (10, 20)\n# Para añadir una tercera dimensión, creamos una nueva tupla\npunto_3d = punto_2d + (30,)</pre>
                <div class="code-output">{output_tupla_p3_crear_nueva}</div>
            </div>
        </div>
        <div class="topic-card">
            <div class="topic-header"><span class="topic-title">Parte 4: Métodos y Operaciones Comunes</span><i class="fas fa-chevron-down expand-icon"></i></div>
            <div class="topic-content">
                <p>Las tuplas tienen muchos menos métodos que las listas, precisamente porque no se pueden modificar.</p>
                <h3>Métodos disponibles: <code>.count()</code> y <code>.index()</code></h3><ul><li><code>.count(valor)</code>: Cuenta cuántas veces aparece un valor.</li><li><code>.index(valor)</code>: Devuelve el índice de la primera aparición del valor (lanza un error si no lo encuentra).</li></ul>
                <pre>notas = (10, 9, 8, 10, 7, 9, 10)\nconteo_10 = notas.count(10)\nindice_8 = notas.index(8)</pre>
                <div class="code-output">{output_tupla_p4_metodos}</div>
                <h3>Ordenamiento con <code>sorted()</code></h3><div class="tip-box">Una tupla no tiene el método <code>.sort()</code>. Para ordenarla, debes usar la función <code>sorted(mi_tupla)</code>, que siempre devuelve una <strong>nueva lista ordenada</strong>, dejando la tupla original intacta.</div>
                <pre>desordenada = (3, 1, 4, 1, 5, 9, 2)\nlista_ordenada = sorted(desordenada)</pre>
                <div class="code-output">{output_tupla_p4_sorted}</div>
            </div>
        </div>
        <div class="topic-card">
            <div class="topic-header"><span class="topic-title">Parte 5: Casos de Uso y Ventajas</span><i class="fas fa-chevron-down expand-icon"></i></div>
            <div class="topic-content">
                <p>¿Por qué usar tuplas si las listas son más flexibles? La inmutabilidad ofrece ventajas clave en ciertos escenarios.</p>
                <h3>1. Claves de Diccionario</h3><p>Las claves de un diccionario deben ser inmutables. Por lo tanto, puedes usar una tupla como clave, pero no una lista. Esto es útil para datos compuestos, como coordenadas.</p>
                <pre># Una tupla PUEDE ser una clave de diccionario\nmapa_precios = {{('Madrid', 'Barcelona'): 120, ('Sevilla', 'Valencia'): 95}}\n\n# una lista NO PUEDE\n# mapa_precios_error = {{['Madrid', 'Barcelona']: 120}} # TypeError!</pre>
                <div class="code-output">{output_tupla_p5_dict_key}</div>
                <h3>2. Retorno de Múltiples Valores en Funciones</h3><p>Es una práctica común y muy "Pythonic" que una función devuelva múltiples valores como una tupla. El código que llama a la función puede "desempaquetar" fácilmente la tupla en variables individuales.</p>
                <pre>def obtener_stats(numeros):\n    minimo = min(numeros)\n    maximo = max(numeros)\n    suma = sum(numeros)\n    return minimo, maximo, suma # Python empaqueta esto en una tupla\n\n# Desempaquetado de la tupla devuelta\nmin_val, max_val, sum_val = obtener_stats([1, 5, 2, 8])</pre>
                <div class="code-output">{output_tupla_p5_unpacking}</div>
            </div>
        </div>
    </div>
  </div>
  <script>
    (function() {{
        document.querySelectorAll('.topic-header').forEach(header => {{
            header.addEventListener('click', () => {{
                document.querySelectorAll('.topic-card.open').forEach(openCard => {{
                    if (openCard !== header.parentElement) {{
                        openCard.classList.remove('open');
                    }}
                }});
                header.parentElement.classList.toggle('open');
            }});
        }});
    }})();
  </script>
</body>
</html>
"""

# ==============================================================================
# 2. LÓGICA PYTHON PARA GENERAR LOS RESULTADOS DE TUPLAS
# ==============================================================================

# Parte 1: Creación
tupla_vacia = ()
tupla_con_elementos = (1, "hola", 3.14, True)
tupla_un_elemento = ("solitario",)
tupla_desde_iterable = tuple("python")
output_tupla_p1_creacion = (f"Tupla vacía literal: {tupla_vacia} (tipo: {type(tupla_vacia)})\n"
                           f"Tupla con elementos heterogéneos: {tupla_con_elementos}\n"
                           f"Tupla de un solo elemento (¡nota la coma!): {tupla_un_elemento} (tipo: {type(tupla_un_elemento)})\n"
                           f"Tupla creada desde un string: {tupla_desde_iterable}")

# Parte 2: Acceso
elementos_tupla = ('P', 'y', 't', 'h', 'o', 'n')
output_tupla_p2_acceso = (f"Tupla de ejemplo: {elementos_tupla}\n"
                         f"Primer elemento con [0]: '{elementos_tupla[0]}'\n"
                         f"Último elemento con [-1]: '{elementos_tupla[-1]}'\n"
                         f"Slice [1:4] (devuelve una nueva tupla): {elementos_tupla[1:4]}\n"
                         f"Tupla invertida con [::-1]: {elementos_tupla[::-1]}")

# Parte 3: Inmutabilidad
coordenadas = (10, 20)
error_msg = ""
try:
    coordenadas[0] = 15
except TypeError as e:
    error_msg = f"¡Error capturado con éxito!\n{type(e).__name__}: {e}"
output_tupla_p3_inmutabilidad = error_msg

punto_2d = (10, 20)
punto_3d = punto_2d + (30,)
output_tupla_p3_crear_nueva = (f"Tupla original: {punto_2d}\n"
                              f"Nueva tupla creada: {punto_3d} (id original: {id(punto_2d)}, id nueva: {id(punto_3d)})")

# Parte 4: Métodos
notas = (10, 9, 8, 10, 7, 9, 10)
output_tupla_p4_metodos = (f"Tupla de notas: {notas}\n"
                         f"Veces que aparece el 10 (.count(10)): {notas.count(10)}\n"
                         f"Índice de la primera aparición del 8 (.index(8)): {notas.index(8)}")

desordenada = (3, 1, 4, 1, 5, 9, 2)
lista_ordenada = sorted(desordenada)
output_tupla_p4_sorted = (f"Tupla original: {desordenada}\n"
                        f"Resultado de sorted(tupla): {lista_ordenada}\n"
                        f"Tipo del resultado: {type(lista_ordenada)} <-- ¡Devuelve una LISTA!")

# Parte 5: Casos de Uso
mapa_precios = {('Madrid', 'Barcelona'): 120, ('Sevilla', 'Valencia'): 95}
output_tupla_p5_dict_key = f"Precio del trayecto ('Madrid', 'Barcelona'): {mapa_precios[('Madrid', 'Barcelona')]} €"

def obtener_stats(numeros):
    minimo = min(numeros)
    maximo = max(numeros)
    suma = sum(numeros)
    return minimo, maximo, suma

resultado_tupla = obtener_stats([1, 5, 2, 8])
min_val, max_val, sum_val = resultado_tupla
output_tupla_p5_unpacking = (f"La función devolvió la tupla: {resultado_tupla}\n"
                           f"Valor mínimo desempaquetado: {min_val}\n"
                           f"Valor máximo desempaquetado: {max_val}\n"
                           f"Suma desempaquetada: {sum_val}")

# ==============================================================================
# 3. INYECTAR LOS RESULTADOS EN LA PLANTILLA DE TUPLAS
# ==============================================================================
final_html_tupla = html_template_tupla.format(
    output_tupla_p1_creacion=output_tupla_p1_creacion,
    output_tupla_p2_acceso=output_tupla_p2_acceso,
    output_tupla_p3_inmutabilidad=output_tupla_p3_inmutabilidad,
    output_tupla_p3_crear_nueva=output_tupla_p3_crear_nueva,
    output_tupla_p4_metodos=output_tupla_p4_metodos,
    output_tupla_p4_sorted=output_tupla_p4_sorted,
    output_tupla_p5_dict_key=output_tupla_p5_dict_key,
    output_tupla_p5_unpacking=output_tupla_p5_unpacking
)

# Renderizar el resultado en el notebook.
display(HTML(final_html_tupla))
# Out:
# <!DOCTYPE html>
# <html lang="es">
# <head>
#   <!-- El head y el style son idénticos al original, solo cambia el título -->
#   <meta charset="UTF-8">
#   <title>Guía Interactiva de Tuplas en Python</title>
#   <link href="https://fonts.googleapis.com/css2?family=Inter:wght@300;400;500;600;700;800&family=JetBrains+Mono:wght@400;500&display=swap" rel="stylesheet">
#   <link href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.4.0/css/all.min.css" rel="stylesheet">
#   <style>
#     :root {
#       --bg-primary: #1a1a2e; --bg-secondary: rgba(27, 40, 69, 0.85); --bg-tertiary: rgba(45, 55, 72, 0.7);
#       --text-primary: #e0e0e0; --text-secondary: #a0aec0; --accent-primary: #4eacfa; --accent-secondary: #c471ed;
#       --accent-gradient: linear-gradient(135deg, var(--accent-primary) 0%, var(--accent-secondary) 100%);
#       --border-color: rgba(255, 255, 255, 0.15); --shadow-card: 0 15px 35px rgba(0, 0, 0, 0.2);
# ...

# %%
# Celda 1
print("--- Creación de Tuplas ---")

# 1. Usando paréntesis () (la forma más común)
tupla_vacia = ()
tupla_con_elementos = (1, "hola", 3.14, True) # También pueden contener tipos de datos mezclados

# 2. Usando el constructor tuple() para convertir otro iterable (como una lista o un string)
tupla_desde_lista = tuple([1, 2, 3])
tupla_desde_string = tuple("python")

# 3. ¡Caso especial y muy importante! Tupla de un solo elemento
#    Se necesita una coma al final para que Python no lo confunda con un número entre paréntesis.
tupla_un_elemento = (42,)
no_es_una_tupla = (42) # Esto es simplemente el número 42

print(f"Una tupla vacía: {tupla_vacia}")
print(f"El tipo de dato es: {type(tupla_vacia)}")
print(f"Una tupla con elementos variados: {tupla_con_elementos}")
print(f"Una tupla creada desde una lista: {tupla_desde_lista}")
print(f"Una tupla creada desde el string 'python': {tupla_desde_string}")
print("-" * 20)
print(f"Tupla de un solo elemento (nota la coma): {tupla_un_elemento}, tipo: {type(tupla_un_elemento)}")
print(f"Esto NO es una tupla: {no_es_una_tupla}, tipo: {type(no_es_una_tupla)}")
# Out:
# --- Creación de Tuplas ---
# Una tupla vacía: ()
# El tipo de dato es: <class 'tuple'>
# Una tupla con elementos variados: (1, 'hola', 3.14, True)
# Una tupla creada desde una lista: (1, 2, 3)
# Una tupla creada desde el string 'python': ('p', 'y', 't', 'h', 'o', 'n')
# --------------------
# Tupla de un solo elemento (nota la coma): (42,), tipo: <class 'tuple'>
# Esto NO es una tupla: 42, tipo: <class 'int'>

# %%
# Celda 2
print("--- Acceso a Elementos (Funciona igual que en las listas) ---")

elementos = ('P', 'y', 't', 'h', 'o', 'n')

# 1. Acceso por índice (empieza en 0)
primer_elemento = elementos[0]

# 2. Acceso con índice negativo (el -1 es el último)
ultimo_elemento = elementos[-1]

# 3. Slicing o rebanado para obtener una sub-tupla
sub_tupla = elementos[1:4] # Elementos desde el índice 1 hasta el 3

# 4. Slicing para invertir la tupla
tupla_invertida = elementos[::-1]

print(f"Tupla original: {elementos}")
print(f"Primer elemento [0]: {primer_elemento}")
print(f"Último elemento [-1]: {ultimo_elemento}")
print(f"Sub-tupla con slice [1:4]: {sub_tupla}")
print(f"Tupla invertida con slice [::-1]: {tupla_invertida}")
# Out:
# --- Acceso a Elementos (Funciona igual que en las listas) ---
# Tupla original: ('P', 'y', 't', 'h', 'o', 'n')
# Primer elemento [0]: P
# Último elemento [-1]: n
# Sub-tupla con slice [1:4]: ('y', 't', 'h')
# Tupla invertida con slice [::-1]: ('n', 'o', 'h', 't', 'y', 'P')

# %%
# Celda 3
print("--- La Inmutabilidad en Acción (Intentos de Modificación) ---")

coordenadas = (1920, 1080)
print(f"Tupla original: {coordenadas}")

# 1. Intentar cambiar un elemento por su índice (¡esto fallará!)
try:
    coordenadas[0] = 1280
except TypeError as e:
    print(f"\nError al intentar cambiar un elemento (coordenadas[0] = 1280):")
    print(f"  -> {e}")

# 2. Intentar añadir un elemento (las tuplas no tienen el método .append())
try:
    coordenadas.append(720)
except AttributeError as e:
    print(f"\nError al intentar añadir un elemento (coordenadas.append(720)):")
    print(f"  -> {e}")

print("\nLa tupla original permanece intacta:", coordenadas)
# Out:
# --- La Inmutabilidad en Acción (Intentos de Modificación) ---
# Tupla original: (1920, 1080)
#
# Error al intentar cambiar un elemento (coordenadas[0] = 1280):
#   -> 'tuple' object does not support item assignment
#
# Error al intentar añadir un elemento (coordenadas.append(720)):
#   -> 'tuple' object has no attribute 'append'
#
# La tupla original permanece intacta: (1920, 1080)

# %%
# Celda 4
print("--- 'Modificar' Creando una Nueva Tupla ---")

punto_2d = (10, 20)
print(f"Tupla original (punto 2D): {punto_2d}")
print(f"ID de memoria de la tupla original: {id(punto_2d)}")

# Para "añadir" un elemento, creamos una nueva tupla concatenando la original con otra
punto_3d = punto_2d + (30,) # Nota la coma para crear una tupla de un elemento

print(f"\nNueva tupla (punto 3D): {punto_3d}")
print(f"ID de memoria de la nueva tupla: {id(punto_3d)}")
print("\n¡Observa que el ID de memoria es diferente! Hemos creado un objeto completamente nuevo.")
# Out:
# --- 'Modificar' Creando una Nueva Tupla ---
# Tupla original (punto 2D): (10, 20)
# ID de memoria de la tupla original: 139994615980224
#
# Nueva tupla (punto 3D): (10, 20, 30)
# ID de memoria de la nueva tupla: 139994606721280
#
# ¡Observa que el ID de memoria es diferente! Hemos creado un objeto completamente nuevo.

# %%
# Celda 5
print("--- Métodos de Tupla y Desempaquetado (Unpacking) ---")

notas = (10, 9, 7, 8, 9, 9, 10)

# 1. Métodos .count() y .index()
conteo_de_9 = notas.count(9)
posicion_del_8 = notas.index(8)

print(f"Tupla de notas: {notas}")
print(f"El número 9 aparece {conteo_de_9} veces (.count(9))")
print(f"El número 8 está en la posición {posicion_del_8} (.index(8))")

# 2. Desempaquetado de Tuplas (Tuple Unpacking)
#    Se asignan los elementos de una tupla a variables individuales.
#    ¡Esto es extremadamente útil y muy Pythonic!
persona = ("Ana", "García", 30)
nombre, apellido, edad = persona

print("\n--- Desempaquetado ---")
print(f"Tupla original: {persona}")
print(f"Variable 'nombre': {nombre}")
print(f"Variable 'apellido': {apellido}")
print(f"Variable 'edad': {edad}")
# Out:
# --- Métodos de Tupla y Desempaquetado (Unpacking) ---
# Tupla de notas: (10, 9, 7, 8, 9, 9, 10)
# El número 9 aparece 3 veces (.count(9))
# El número 8 está en la posición 3 (.index(8))
#
# --- Desempaquetado ---
# Tupla original: ('Ana', 'García', 30)
# Variable 'nombre': Ana
# Variable 'apellido': García
# Variable 'edad': 30

# %%
# Celda 6
print("--- Casos de Uso Prácticos ---")

# 1. Devolver múltiples valores de una función
def obtener_min_max(datos):
    """Devuelve el valor mínimo y máximo de una secuencia."""
    return (min(datos), max(datos)) # Python empaqueta los valores en una tupla

numeros = [4, 1, 88, -10, 42]
minimo, maximo = obtener_min_max(numeros) # Se desempaqueta el resultado directamente

print("1. Devolviendo múltiples valores de una función:")
print(f"  Los números son: {numeros}")
print(f"  El valor mínimo es {minimo} y el máximo es {maximo}")


# 2. Usar como claves en un diccionario
#    Las claves de un diccionario DEBEN ser inmutables. Una tupla lo es, una lista no.
capitales = {
    ("España", "Europa"): "Madrid",
    ("Colombia", "América"): "Bogotá",
    ("Japón", "Asia"): "Tokio"
}
# Esto fallaría: capitales_error = {["España", "Europa"]: "Madrid"} -> TypeError

clave_consulta = ("España", "Europa")
print("\n2. Usando tuplas como claves de diccionario:")
print(f"  La capital de {clave_consulta} es: {capitales[clave_consulta]}")
# Out:
# --- Casos de Uso Prácticos ---
# 1. Devolviendo múltiples valores de una función:
#   Los números son: [4, 1, 88, -10, 42]
#   El valor mínimo es -10 y el máximo es 88
#
# 2. Usando tuplas como claves de diccionario:
#   La capital de ('España', 'Europa') es: Madrid
