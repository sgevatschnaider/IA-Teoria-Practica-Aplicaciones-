# %% [markdown]
# <a href="https://colab.research.google.com/github/sgevatschnaider/IA-Teoria-Practica/blob/main/notebooks/Introducci%C3%B3n_a_SQL%2C_Inteligencia_Artificical_y_Seguridad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-
# Importación de librerías necesarias
from IPython.display import display, HTML
import html # Para escapar caracteres especiales en los títulos

# --- 1. BLOQUES DE CONTENIDO AMPLIADO Y ENRIQUECIDO ---

# --- Bloque de Conclusión ---
conclusion_html_block = """
<div class="content-block">
    <h2>Conclusión: Eligiendo la Herramienta Adecuada para el Trabajo</h2>
    <p>La era del "one-size-fits-all" en las bases de datos ha terminado. La elección correcta ya no es simplemente "SQL vs. NoSQL", sino una decisión estratégica que debe alinearse con la naturaleza de los datos, los requisitos de escalabilidad y los patrones de consulta de la aplicación. [13, 18]</p>
    <p>Las bases de datos relacionales siguen siendo la columna vertebral de los sistemas transaccionales que exigen consistencia (ACID). [3, 10] Por otro lado, el ecosistema NoSQL ofrece la flexibilidad y escalabilidad horizontal (BASE) necesarias para el Big Data y las aplicaciones web a gran escala. [3, 20] Con la irrupción de la IA, nuevas categorías como las <strong>Bases de Datos Vectoriales</strong> se vuelven indispensables para tareas de búsqueda semántica y RAG. [2, 24] Comprender las fortalezas y debilidades de cada tipo es una habilidad fundamental para cualquier arquitecto de software o científico de datos moderno.</p>
</div>
"""

# --- Contenido Principal para el Acordeón (TEMA: GUÍA DE BASES DE DATOS) ---
database_types_data = [
    {
        "titulo": "1. ¿Qué es una Base de Datos?",
        "contenido": """
            <h4>Definición Fundamental</h4>
            <p>Una base de datos es un <strong>sistema de información organizado</strong> diseñado para almacenar, gestionar, actualizar y recuperar datos de manera eficiente, estructurada y segura. Actúa como el cerebro persistente de una aplicación, permitiendo que los datos sobrevivan más allá de una sola sesión de usuario y sean accesibles de forma concurrente por múltiples sistemas o usuarios. [34]</p>
            <h4>Componentes Clave de un Sistema de Base de Datos (DBMS):</h4>
            <ul>
                <li><strong>Motor de Almacenamiento:</strong> El componente de bajo nivel que gestiona la escritura y lectura de datos en el disco o la memoria.</li>
                <li><strong>Motor de Consultas:</strong> Parsea, optimiza y ejecuta las solicitudes de datos (ej. consultas SQL).</li>
                <li><strong>Sistema de Gestión de Transacciones:</strong> Asegura la integridad y consistencia de los datos durante las operaciones (ver ACID vs. BASE).</li>
                <li><strong>Capa de Seguridad:</strong> Gestiona la autenticación de usuarios y la autorización de permisos.</li>
            </ul>
        """
    },
    {
        "titulo": "2. El Dilema Fundamental: Teorema CAP y ACID vs. BASE",
        "contenido": """
            <h4>El Teorema CAP: El Trilema de los Sistemas Distribuidos</h4>
            <p>El <strong>Teorema CAP</strong> (también conocido como Teorema de Brewer) es un principio fundamental en la ciencia de la computación que afirma que un almacén de datos distribuido solo puede garantizar <strong>dos de las siguientes tres propiedades</strong> simultáneamente en caso de un fallo de red: [5, 6, 11, 15, 26]</p>
            <ul>
                <li><strong>Consistencia (Consistency):</strong> Todos los nodos del sistema ven los mismos datos en el mismo momento. Cada lectura recibe la escritura más reciente o un error.</li>
                <li><strong>Disponibilidad (Availability):</strong> Cada solicitud recibe una respuesta (sin error), aunque no se garantice que contenga la escritura más reciente.</li>
                <li><strong>Tolerancia a Particiones (Partition Tolerance):</strong> El sistema continúa operando a pesar de que se interrumpa la comunicación entre los nodos (una "partición de red").</li>
            </ul>
            <p>Dado que en los sistemas distribuidos (la base de la nube moderna) la tolerancia a particiones (P) es una necesidad, la elección real es entre Consistencia (CP) y Disponibilidad (AP).</p>

            <h4>ACID vs. BASE: Dos Filosofías de Transacción</h4>
            <div class="table-container">
                <table>
                    <thead><tr><th>Propiedad</th><th>Modelo ACID (Prioriza Consistencia)</th><th>Modelo BASE (Prioriza Disponibilidad)</th></tr></thead>
                    <tbody>
                        <tr><td><strong>Definición</strong></td><td><strong>A</strong>tomicidad, <strong>C</strong>onsistencia, <strong>A</strong>islamiento (Isolation), <strong>D</strong>urabilidad. [37]</td><td><strong>B</strong>asically <strong>A</strong>vailable, <strong>S</strong>oft state, <strong>E</strong>ventual consistency. [3, 40]</td></tr>
                        <tr><td><strong>Ideal Para</strong></td><td>Sistemas transaccionales críticos: banca, e-commerce, ERPs. [31]</td><td>Sistemas a gran escala: redes sociales, IoT, análisis de Big Data. [31]</td></tr>
                        <tr><td><strong>Ejemplo</strong></td><td>Una transferencia bancaria: o se completan todos los pasos (débito y crédito) o no se hace nada (atomicidad). [17]</td><td>El "like" de una red social: el contador puede tardar unos segundos en actualizarse en todos los servidores (consistencia eventual).</td></tr>
                        <tr><td><strong>Bases de Datos Típicas</strong></td><td>Relacionales (PostgreSQL, MySQL).</td><td>NoSQL (Cassandra, DynamoDB, Redis). [37]</td></tr>
                    </tbody>
                </table>
            </div>
        """
    },
    {
        "titulo": "3. Bases de Datos Relacionales (RDBMS / SQL)",
        "contenido": """
            <h4>El Modelo Estructurado</h4>
            <p>Son el tipo de base de datos más tradicional y extendido, basadas en el modelo relacional. Organizan los datos en <strong>tablas</strong> (relaciones) que contienen <strong>filas</strong> (tuplas) y <strong>columnas</strong> (atributos). [10, 16] La integridad y las relaciones entre tablas se mantienen mediante claves primarias y foráneas.</p>
            <ul>
                <li><strong>Lenguaje:</strong> Usan <strong>SQL (Structured Query Language)</strong> para definir, manipular y consultar los datos. [9]</li>
                <li><strong>Modelo de Consistencia:</strong> Fuertemente <strong>ACID</strong>. [49]</li>
                <li><strong>Escalabilidad:</strong> Tradicionalmente escalan de forma <strong>vertical</strong> (aumentando la potencia de un único servidor), aunque los sistemas modernos han mejorado la escalabilidad horizontal. [47]</li>
                <li><strong>Extensiones de Archivo:</strong> <code>.sql</code> (scripts), <code>.db</code>, <code>.sqlite</code>, <code>.mdf</code> (SQL Server). [34, 39, 42, 48]</li>
            </ul>
            <h4>Ejemplo de Modelo de Datos Relacional:</h4>
            <div class="content-block" style="background-color: #2d2d2d; color: #f0f0f0; font-family: 'JetBrains Mono', monospace; padding: 1rem; border-radius: 8px;">
<pre><code>CREATE TABLE Autores (
    autor_id INT PRIMARY KEY,
    nombre TEXT NOT NULL
);

CREATE TABLE Libros (
    libro_id INT PRIMARY KEY,
    titulo TEXT NOT NULL,
    autor_id INT,
    FOREIGN KEY (autor_id) REFERENCES Autores(autor_id)
);</code></pre>
            </div>
            <p><strong>Ejemplos Populares:</strong> PostgreSQL, MySQL, Oracle Database, Microsoft SQL Server, SQLite. [16]</p>
        """
    },
    {
        "titulo": "4. Bases de Datos No Relacionales (NoSQL)",
        "contenido": """
            <h4>Flexibilidad y Escalabilidad</h4>
            <p>Engloban una amplia variedad de bases de datos que no utilizan el modelo relacional. Están diseñadas para manejar grandes volúmenes de datos no estructurados o semi-estructurados y para escalar horizontalmente (añadiendo más servidores). [16, 20, 46]</p>

            <h4>a. Documentales</h4>
            <p>Almacenan datos en documentos flexibles, similares a JSON. Cada documento puede tener su propia estructura. [16]</p>
            <p><strong>Ideal para:</strong> Gestión de contenidos, catálogos de productos, perfiles de usuario. [18]</p>
            <p><strong>Ejemplo de Modelo (MongoDB):</strong></p>
            <div class="content-block" style="background-color: #2d2d2d; color: #f0f0f0; font-family: 'JetBrains Mono', monospace; padding: 1rem; border-radius: 8px;">
<pre><code>{
  "_id": "ObjectId('...')",
  "titulo": "Cien Años de Soledad",
  "publicado": 1967,
  "autor": {
    "nombre": "Gabriel García Márquez",
    "nacionalidad": "Colombiano"
  },
  "generos": ["Realismo Mágico", "Novela"]
}</code></pre>
            </div>
            <p><strong>Ejemplos Populares:</strong> MongoDB, Couchbase, Amazon DocumentDB. [16]</p>

            <h4>b. Clave-Valor</h4>
            <p>El modelo más simple. Almacenan datos como un diccionario gigante: cada dato tiene una clave única para su recuperación. Son extremadamente rápidas. [18]</p>
            <p><strong>Ideal para:</strong> Caching, gestión de sesiones de usuario, leaderboards de juegos. [7, 19, 29, 35]</p>
            <p><strong>Ejemplos Populares:</strong> Redis, Amazon DynamoDB, Memcached.</p>

            <h4>c. Columnar Ancha (Wide-Column)</h4>
            <p>Almacenan datos en familias de columnas en lugar de filas. Son óptimas para consultas analíticas sobre grandes volúmenes de datos, ya que solo leen las columnas necesarias. [9, 36]</p>
            <p><strong>Ideal para:</strong> Big Data, telemetría, logs, sistemas de recomendación. [18]</p>
            <p><strong>Ejemplos Populares:</strong> Apache Cassandra, Google Bigtable, HBase. [16]</p>

            <h4>d. Grafos</h4>
            <p>Diseñadas para modelar y consultar datos con relaciones complejas. Utilizan nodos para representar entidades y aristas para representar las conexiones entre ellas. [36]</p>
            <p><strong>Ideal para:</strong> Redes sociales, detección de fraude, motores de recomendación. [18]</p>
            <p><strong>Ejemplos Populares:</strong> Neo4j, Amazon Neptune, ArangoDB. [16]</p>
        """
    },
    {
        "titulo": "5. Categorías Especializadas y Emergentes",
        "contenido": """
            <h4>Soluciones para Problemas Específicos</h4>

            <h4>a. Bases de Datos en Memoria (In-Memory)</h4>
            <p>Almacenan la totalidad o la mayor parte de los datos en la memoria RAM en lugar del disco, lo que proporciona tiempos de respuesta de microsegundos. [7, 19, 29, 33, 35]</p>
            <p><strong>Ideal para:</strong> Caching de alto rendimiento, análisis en tiempo real, subastas online. [19]</p>
            <p><strong>Ejemplos:</strong> Redis, SAP HANA, Memcached.</p>

            <h4>b. Bases de Datos de Series Temporales (Time-Series)</h4>
            <p>Optimizadas para almacenar y consultar datos que son puntos medidos a lo largo del tiempo (datos con timestamp). [10, 25, 32]</p>
            <p><strong>Ideal para:</strong> Monitorización de sistemas (DevOps), datos de sensores (IoT), mercados financieros. [41, 45]</p>
            <p><strong>Ejemplos:</strong> InfluxDB, Prometheus, TimescaleDB. [10]</p>

            <h4>c. Bases de Datos Vectoriales (Vector DB)</h4>
            <p><strong>(Cruciales para la IA)</strong> Diseñadas para almacenar y buscar en datos de alta dimensionalidad, conocidos como "vector embeddings". En lugar de buscar por coincidencias exactas, buscan por similitud semántica. [2, 24, 27]</p>
            <p><strong>Ideal para:</strong> Búsqueda de imágenes/texto por significado, IA generativa (RAG), sistemas de recomendación, detección de anomalías. [21, 30]</p>
            <p><strong>Ejemplos:</strong> Pinecone, Milvus, Chroma, Weaviate. [2, 30]</p>

            <h4>d. NewSQL</h4>
            <p>Una nueva generación de bases de datos relacionales que busca combinar la consistencia <strong>ACID</strong> de SQL con la <strong>escalabilidad horizontal</strong> de NoSQL. [1, 4, 8, 12, 14]</p>
            <p><strong>Ideal para:</strong> Sistemas financieros, plataformas de e-commerce y OLTP (Procesamiento de Transacciones en Línea) a gran escala. [4, 12]</p>
            <p><strong>Ejemplos:</strong> CockroachDB, Google Spanner, NuoDB, YugabyteDB. [14, 23, 44]</p>

            <h4>e. Bases de Datos Distribuidas</h4>
            <p>Son sistemas donde los datos no se almacenan en un solo lugar, sino que se distribuyen en múltiples máquinas, a menudo en diferentes ubicaciones geográficas. Pueden ser SQL o NoSQL. [22, 23, 28, 43]</p>
            <p><strong>Ideal para:</strong> Alta disponibilidad, recuperación ante desastres y baja latencia para usuarios globales. [23]</p>
            <p><strong>Ejemplos:</strong> Amazon Aurora, Google Spanner, Cassandra, CockroachDB. [22, 23]</p>
        """
    },
    {
        "titulo": "6. Comparativa Estratégica",
        "contenido": """
        <div class="table-container">
            <table>
                <thead>
                    <tr>
                        <th>Tipo de Base de Datos</th>
                        <th>Modelo de Datos Principal</th>
                        <th>Consistencia</th>
                        <th>Escalabilidad Típica</th>
                        <th>Mejor Caso de Uso</th>
                    </tr>
                </thead>
                <tbody>
                    <tr>
                        <td><strong>Relacional (SQL)</strong></td>
                        <td>Tablas y Relaciones</td>
                        <td>ACID (Fuerte)</td>
                        <td>Vertical</td>
                        <td>Sistemas transaccionales, datos estructurados.</td>
                    </tr>
                    <tr>
                        <td><strong>Documental</strong></td>
                        <td>Documentos (JSON/BSON)</td>
                        <td>BASE (Eventual)</td>
                        <td>Horizontal</td>
                        <td>Contenido semi-estructurado, catálogos.</td>
                    </tr>
                    <tr>
                        <td><strong>Clave-Valor</strong></td>
                        <td>Pares Clave-Valor</td>
                        <td>BASE (Eventual)</td>
                        <td>Horizontal</td>
                        <td>Caching, sesiones, alta velocidad de lectura/escritura.</td>
                    </tr>
                    <tr>
                        <td><strong>Columnar Ancha</strong></td>
                        <td>Familias de Columnas</td>
                        <td>BASE (Configurable)</td>
                        <td>Horizontal</td>
                        <td>Big Data, analítica, telemetría.</td>
                    </tr>
                    <tr>
                        <td><strong>Grafos</strong></td>
                        <td>Nodos y Aristas</td>
                        <td>ACID/BASE (Varía)</td>
                        <td>Mixta</td>
                        <td>Análisis de redes y relaciones complejas.</td>
                    </tr>
                    <tr>
                        <td><strong>Series Temporales</strong></td>
                        <td>Puntos en el Tiempo</td>
                        <td>Varía</td>
                        <td>Horizontal</td>
                        <td>Monitorización, IoT, datos financieros.</td>
                    </tr>
                    <tr>
                        <td><strong>Vectorial</strong></td>
                        <td>Vectores de alta dimensión</td>
                        <td>BASE (Eventual)</td>
                        <td>Horizontal</td>
                        <td>Búsqueda semántica, IA generativa, similitud.</td>
                    </tr>
                    <tr>
                        <td><strong>NewSQL</strong></td>
                        <td>Tablas y Relaciones</td>
                        <td>ACID (Fuerte)</td>
                        <td>Horizontal</td>
                        <td>Sistemas transaccionales a gran escala (OLTP).</td>
                    </tr>
                </tbody>
            </table>
        </div>
        """
    }
]



# --- LÓGICA DE GENERACIÓN (SIN CAMBIOS) ---
def generar_tarjetas_definiciones(datos):
    html_generado = []
    for seccion in datos:
        titulo_escapado = html.escape(seccion['titulo'])
        contenido_html = seccion['contenido']
        plantilla_seccion = f"""
        <div class="topic-card">
            <div class="topic-header">
                <span class="topic-title">{titulo_escapado}</span>
                <i class="fas fa-chevron-down expand-icon"></i>
            </div>
            <div class="topic-content">
                {contenido_html}
            </div>
        </div>
        """
        html_generado.append(plantilla_seccion)
    return "\n".join(html_generado)

# --- PRE-CÁLCULO DEL CONTENIDO DINÁMICO ---
contenido_dinamico_html = generar_tarjetas_definiciones(database_types_data)

# --- PLANTILLA PROFESIONAL (CON PALETA DE COLORES DE DATOS) ---
plantilla_profesional = """
<!DOCTYPE html>
<html lang="es">
<head>
  <meta charset="UTF-8">
  <meta name="viewport" content="width=device-width, initial-scale=1.0">
  <title>{main_title}</title>
  <link href="https://fonts.googleapis.com/css2?family=Inter:wght@300;400;500;600;700;800&family=JetBrains+Mono:wght@400;500&display=swap" rel="stylesheet">
  <link href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.4.0/css/all.min.css" rel="stylesheet">
  <style>
    :root {{
      --bg-primary: linear-gradient(135deg, #2c3e50 0%, #3498db 100%);
      --bg-secondary: rgba(26, 32, 44, 0.85);
      --bg-tertiary: rgba(45, 55, 72, 0.7);
      --text-primary: #f7fafc;
      --text-secondary: #a0aec0;
      --accent-primary: #3498db;
      --accent-secondary: #2980b9;
      --accent-gradient: linear-gradient(135deg, var(--accent-primary) 0%, var(--accent-secondary) 100%);
      --border-color: rgba(255, 255, 255, 0.15);
      --shadow-card: 0 15px 35px rgba(0, 0, 0, 0.1);
      --border-radius: 20px;
      --transition: all 0.4s cubic-bezier(0.25, 0.8, 0.25, 1);
    }}
    [data-theme="light"] {{
      --bg-primary: linear-gradient(135deg, #e0eafc 0%, #cfdef3 100%);
      --bg-secondary: rgba(255, 255, 255, 0.85);
      --bg-tertiary: rgba(248, 250, 252, 0.8);
      --text-primary: #2c3e50;
      --text-secondary: #34495e;
      --accent-primary: #2980b9;
      --accent-secondary: #3498db;
      --border-color: rgba(226, 232, 240, 0.8);
    }}
    * {{ margin: 0; padding: 0; box-sizing: border-box; }}
    html {{ scroll-behavior: smooth; }}
    body {{ font-family: 'Inter', sans-serif; line-height: 1.8; background: var(--bg-primary); color: var(--text-primary); transition: var(--transition); min-height: 100vh; position: relative; overflow-x: hidden; }}
    .particles {{ position: fixed; top: 0; left: 0; width: 100%; height: 100%; pointer-events: none; z-index: -1; }}
    .particle {{ position: absolute; border-radius: 50%; animation: float 25s infinite linear; opacity: 0; background: rgba(255, 255, 255, 0.6);}}
    @keyframes float {{ 0% {{ transform: translateY(100vh) rotate(0deg); opacity: 0; }} 10%, 90% {{ opacity: 0.6; }} 100% {{ transform: translateY(-10vh) rotate(360deg); opacity: 0; }} }}

    .container {{ max-width: 1100px; margin: 0 auto; padding: 2rem; z-index: 1; }}
    .header {{ text-align: center; margin-bottom: 3rem; position: relative; }}
    .main-title {{ font-size: clamp(2.2rem, 5vw, 3.8rem); font-weight: 800; background: var(--accent-gradient); -webkit-background-clip: text; -webkit-text-fill-color: transparent; background-clip: text; margin-bottom: 1rem; }}

    .theme-toggle {{ position: fixed; top: 2rem; right: 2rem; width: 60px; height: 60px; border: 1px solid var(--border-color); border-radius: 50%; background: var(--bg-secondary); backdrop-filter: blur(15px); box-shadow: var(--shadow-card); cursor: pointer; display: flex; align-items: center; justify-content: center; font-size: 1.4rem; color: var(--accent-primary); transition: var(--transition); z-index: 1000; }}
    .theme-toggle:hover {{ transform: scale(1.15) rotate(180deg); }}

    .content-block {{
        background: var(--bg-secondary); backdrop-filter: blur(20px); border-radius: var(--border-radius);
        box-shadow: var(--shadow-card); border: 2px solid var(--border-color);
        padding: 2rem; margin-bottom: 2rem;
    }}
    .content-block h2 {{ color: var(--text-primary); margin-bottom: 1rem; }}
    .content-block p, .content-block li {{ color: var(--text-secondary); margin-bottom: 1rem; }}
    .content-block ul {{padding-left: 20px;}}

    .lesson-container {{ display: flex; flex-direction: column; gap: 1.5rem; }}
    .topic-card {{ background: var(--bg-secondary); backdrop-filter: blur(20px); border-radius: var(--border-radius); box-shadow: var(--shadow-card); border: 2px solid var(--border-color); overflow: hidden; transition: var(--transition); }}
    .topic-header {{ cursor: pointer; padding: 1.5rem 2rem; display: flex; justify-content: space-between; align-items: center; }}
    .topic-title {{ font-size: 1.3rem; font-weight: 600; color: var(--text-primary); }}
    .expand-icon {{ font-size: 1.2rem; color: var(--text-secondary); transition: var(--transition); }}
    .topic-card.open .expand-icon {{ transform: rotate(180deg); color: var(--accent-primary); }}
    .topic-content {{ max-height: 0; overflow: hidden; transition: max-height 2.5s ease-in-out, padding 2.5s ease-in-out; background: var(--bg-tertiary); }}
    .topic-card.open .topic-content {{ max-height: 6500px; padding: 1.5rem 2rem; border-top: 1px solid var(--border-color); }}

    .topic-content h4 {{ color: var(--text-primary); margin-top: 1.5rem; margin-bottom: 0.5rem; font-size: 1.1rem; }}
    .topic-content p, .topic-content li {{ color: var(--text-secondary); line-height: 1.7; }}
    .topic-content ul {{ padding-left: 25px; margin-bottom: 1rem; }}
    .topic-content strong {{ color: var(--accent-primary); font-weight: 700; }}
    .table-container {{ overflow-x: auto; margin: 1.5rem 0; }}
    table {{ width: 100%; border-collapse: collapse; }}
    th, td {{ padding: 12px 15px; border: 1px solid var(--border-color); text-align: left; }}
    thead th {{ background-color: var(--bg-tertiary); color: var(--text-primary); font-weight: 600; }}
    tbody tr:nth-child(even) {{ background: rgba(127, 140, 141, 0.05); }}

    footer {{ text-align: center; margin-top: 4rem; padding-top: 2rem; border-top: 1px solid var(--border-color); }}
    footer p {{ color: var(--text-secondary); font-size: 0.9rem; opacity: 0.8; }}
  </style>
</head>
<body data-theme="dark">
  <div class="particles" id="particles-container"></div>
  <div class="theme-toggle" id="themeToggleButton" title="Cambiar tema"><i class="fas fa-moon" id="theme-icon"></i></div>
  <div class="container">
    <header class="header">
      <h1 class="main-title">{main_title}</h1>
    </header>
    <div class="lesson-container">
        {dynamic_content_html}
    </div>
    {conclusion_html}
    <footer>
      <p>{footer_text}</p>
    </footer>
  </div>
  <script>
    (function() {{
        const themeToggleButton = document.getElementById('themeToggleButton');
        const themeIcon = document.getElementById('theme-icon');
        const bodyEl = document.body;
        function setTheme(theme) {{
            bodyEl.setAttribute('data-theme', theme);
            localStorage.setItem('theme', theme);
            if (themeIcon) {{ themeIcon.className = theme === 'dark' ? 'fas fa-sun' : 'fas fa-moon'; }}
        }}
        themeToggleButton.addEventListener('click', () => {{
            const newTheme = (bodyEl.getAttribute('data-theme') || 'dark') === 'light' ? 'light' : 'dark';
            setTheme(newTheme);
        }});
        setTheme(localStorage.getItem('theme') || 'dark');
        document.querySelectorAll('.topic-header').forEach(header => {{
            header.addEventListener('click', () => {{
                header.parentElement.classList.toggle('open');
            }});
        }});
        const container = document.getElementById('particles-container');
        if (container) {{ for (let i = 0; i < 30; i++) {{ const p = document.createElement('div'); p.className = 'particle'; p.style.left = Math.random() * 100 + 'vw'; const size = (Math.random() * 5 + 2); p.style.width = size + 'px'; p.style.height = size + 'px'; p.style.animationDelay = Math.random() * -20 + 's'; p.style.animationDuration = (15 + Math.random() * 10) + 's'; container.appendChild(p); }} }}
        const firstTopic = document.querySelector('.topic-card');
        if(firstTopic) {{ firstTopic.classList.add('open'); }}
    }})();
  </script>
</body>
</html>
"""

# --- INYECCIÓN DINÁMICA Y RENDERIZADO FINAL ---
final_html = plantilla_profesional.format(
    main_title="Guía Completa de Bases de Datos: Tipos, Modelos y Casos de Uso",
    dynamic_content_html=contenido_dinamico_html,
    conclusion_html=conclusion_html_block,
    footer_text="Elaborado por Sergio Gevatschnaider."
)

display(HTML(final_html))
# Out:
# <!DOCTYPE html>
# <html lang="es">
# <head>
#   <meta charset="UTF-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1.0">
#   <title>Guía Completa de Bases de Datos: Tipos, Modelos y Casos de Uso</title>
#   <link href="https://fonts.googleapis.com/css2?family=Inter:wght@300;400;500;600;700;800&family=JetBrains+Mono:wght@400;500&display=swap" rel="stylesheet">
#   <link href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.4.0/css/all.min.css" rel="stylesheet">
#   <style>
#     :root {
#       --bg-primary: linear-gradient(135deg, #2c3e50 0%, #3498db 100%);
#       --bg-secondary: rgba(26, 32, 44, 0.85);
#       --bg-tertiary: rgba(45, 55, 72, 0.7);
#       --text-primary: #f7fafc;
#       --text-secondary: #a0aec0;
#       --accent-primary: #3498db;
#       --accent-secondary: #2980b9;
#       --accent-gradient: linear-gradient(135deg, var(--accent-primary) 0%, var(--accent-secondary) 100%);
#       --border-color: rgba(255, 255, 255, 0.15);
# ...

# %%
# -*- coding: utf-8 -*-
# Importación de librerías necesarias
from IPython.display import display, HTML
import html # Para escapar caracteres especiales en los títulos

# --- 1. BLOQUES DE CONTENIDO AMPLIADO Y ENRIQUECIDO ---

# --- Bloque de Conclusión ---
conclusion_html_block = """
<div class="content-block">
    <h2>Conclusión: La Sinergia como Imperativo Estratégico</h2>
    <p>La convergencia entre SQL, Machine Learning e Inteligencia Artificial ha trascendido la simple cooperación técnica para convertirse en el núcleo de la inteligencia de negocio moderna. SQL ya no es solo un lenguaje para consultar datos; es el andamiaje que estructura, prepara y sirve la información que da vida a los modelos predictivos y a las soluciones de IA. [2] Las organizaciones que dominan esta integración no solo optimizan sus operaciones, sino que desbloquejan capacidades transformadoras: desde la automatización cognitiva hasta la toma de decisiones predictiva en tiempo real. Construir arquitecturas de datos robustas, gobernables y escalables es el factor diferenciador clave para capitalizar el verdadero valor de los datos y liderar en la era de la inteligencia artificial. [4, 5]</p>
</div>
"""

# --- Contenido Principal para el Acordeón (TEMA: INTEGRACIÓN SQL, ML & AI) ---
integration_data = [
    {
        "titulo": "1. Introducción: De Datos a Inteligencia Activa",
        "contenido": """
            <h4>El Ecosistema de Datos Inteligente</h4>
            <p>En la era de la transformación digital, los datos son el motor de la innovación. Sin embargo, su valor no reside en el mero almacenamiento, sino en su activación a través de la inteligencia. Tecnologías como <strong>SQL, Machine Learning (ML) e Inteligencia Artificial (IA)</strong> han dejado de ser silos tecnológicos para conformar un ecosistema integrado y sinérgico. [2] Esta integración es la que permite a las organizaciones pasar de un análisis retrospectivo (¿qué pasó?) a una capacidad predictiva y prescriptiva (¿qué pasará y qué debemos hacer?), automatizando decisiones y creando productos y servicios radicalmente nuevos. [7]</p>
            <blockquote>El objetivo ya no es solo gestionar "Big Data", sino generar "Big Intelligence" a escala.</blockquote>
        """
    },
    {
        "titulo": "2. SQL: La Columna Vertebral del Pipeline de IA",
        "contenido": """
            <h4>Más Allá de la Consulta: Orquestación y Feature Engineering</h4>
            <p>SQL (Structured Query Language) es el lenguaje universal de los datos estructurados y su rol en la era de la IA es más crítico que nunca. [2, 21] Cumple funciones esenciales en todo el ciclo de vida de un modelo:</p>
            <ul>
                <li><strong>Extracción y Transformación (ELT/ETL):</strong> SQL es la herramienta principal para extraer datos de fuentes diversas, limpiarlos, y transformarlos en formatos listos para el análisis.</li>
                <li><strong>Feature Engineering:</strong> Es el proceso de crear nuevas variables (features) que mejoren el poder predictivo de los modelos. SQL es excepcionalmente potente para esto. [6, 21, 26]</li>
                <li><strong>Auditoría y Trazabilidad:</strong> Almacenar las predicciones de los modelos en bases de datos relacionales permite un seguimiento y una validación continua, algo crucial para la gobernanza. [3]</li>
            </ul>
            <h4>Ejemplo de Feature Engineering con SQL Avanzado</h4>
            <p>Creación de variables para un modelo de riesgo crediticio usando Funciones de Ventana y CTEs (Common Table Expressions).</p>
            <div class="content-block" style="background-color: #2d2d2d; color: #f0f0f0; font-family: 'JetBrains Mono', monospace; padding: 1rem; border-radius: 8px;">
                <pre><code>WITH UserMonthlySpend AS (
    SELECT
        user_id,
        DATE_TRUNC('month', transaction_date) AS month,
        SUM(amount) AS monthly_spend
    FROM transactions
    GROUP BY 1, 2
)
SELECT
    user_id,
    monthly_spend,
    -- Gasto comparado con la media del usuario en los últimos 3 meses
    AVG(monthly_spend) OVER (
        PARTITION BY user_id
        ORDER BY month
        ROWS BETWEEN 3 PRECEDING AND 1 PRECEDING
    ) AS avg_spend_last_3m,
    -- Ranking del gasto de este mes dentro del historial del usuario
    RANK() OVER (
        PARTITION BY user_id
        ORDER BY monthly_spend DESC
    ) AS spend_rank
FROM UserMonthlySpend;</code></pre>
            </div>
             <blockquote>Las bases de datos modernas (BigQuery, Snowflake, PostgreSQL) han expandido SQL con tipos de datos para vectores (vector search), funciones geoespaciales y capacidades para ejecutar código Python/Java in-database, desdibujando la línea entre base de datos y entorno de ML. [11]</blockquote>
        """
    },
    {
        "titulo": "3. Machine Learning: Del Dato al Modelo Predictivo",
        "contenido": """
            <h4>El Motor Predictivo del Ecosistema</h4>
            <p>El Machine Learning (ML) utiliza los datos preparados por SQL para construir modelos que identifican patrones y hacen predicciones. La integración es cada vez más nativa:</p>
            <ul>
                <li><strong>Modelos dentro de la Base de Datos:</strong> Plataformas como <strong>Google BigQuery ML</strong>, <strong>Snowflake Cortex</strong>, y <strong>SQL Server ML Services</strong> permiten entrenar, evaluar y servir modelos de ML usando sintaxis SQL, reduciendo drásticamente la fricción y el movimiento de datos. [11, 13, 14, 19]</li>
                <li><strong>MLOps (Machine Learning Operations):</strong> SQL es una pieza clave en los pipelines de MLOps para automatizar el versionado de datos, la validación de la calidad de los datasets de entrenamiento y el monitoreo del rendimiento del modelo en producción. [1, 8, 12, 18]</li>
            </ul>
            <h4>Ejemplo de Pipeline ML Básico con Python y SQL</h4>
            <p>Este código simula la conexión a una base de datos, extrae datos con una consulta SQL y entrena un modelo simple de clasificación.</p>
            <div class="content-block" style="background-color: #2d2d2d; color: #f0f0f0; font-family: 'JetBrains Mono', monospace; padding: 1rem; border-radius: 8px;">
                <pre><code>import pandas as pd
from sqlalchemy import create_engine
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# Simular una conexión a una base de datos en memoria (SQLite)
# En un caso real: 'postgresql://user:pass@host/db'
engine = create_engine('sqlite:///:memory:')

# Crear datos de ejemplo y cargarlos en la BD
df_demo = pd.DataFrame({
    'feature1': [1, 2, 3, 4, 5, 6],
    'feature2': [10, 22, 30, 42, 55, 61],
    'target': [0, 0, 0, 1, 1, 1]
})
df_demo.to_sql('user_data', engine, index=False)

# 1. Usar SQL para extraer los datos
query = "SELECT feature1, feature2, target FROM user_data"
df = pd.read_sql(query, engine)

# 2. Entrenar el modelo
X = df[['feature1', 'feature2']]
y = df['target']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

model = RandomForestClassifier(n_estimators=10)
model.fit(X_train, y_train)

# 3. Evaluar el modelo
preds = model.predict(X_test)
print(f"Precisión del Modelo: {accuracy_score(y_test, preds):.2f}")</code></pre>
            </div>
        """
    },
    {
        "titulo": "4. Inteligencia Artificial: Automatización y Cognición",
        "contenido": """
            <h4>El Marco General de la Inteligencia</h4>
            <p>La IA es el campo más amplio que engloba al ML y otras disciplinas como el Procesamiento del Lenguaje Natural (NLP) y la Visión por Computadora. La integración con SQL es fundamental para las aplicaciones de IA modernas:</p>
            <ul>
                <li><strong>Generative AI y LLMs:</strong> Modelos como GPT-4 interactúan con bases de datos SQL a través de <strong>Agentes SQL</strong>. Estos agentes traducen preguntas en lenguaje natural (ej: "¿cuáles fueron nuestros 5 clientes con más compras el mes pasado?") a consultas SQL, las ejecutan y devuelven una respuesta comprensible. [15, 17, 23, 28]</li>
                <li><strong>Retrieval-Augmented Generation (RAG):</strong> Es una técnica donde un LLM consulta una base de datos (a menudo vectorial, pero también SQL) para obtener información actualizada y específica antes de generar una respuesta. Esto fundamenta las respuestas de la IA en datos verificables de la empresa. [29]</li>
                <li><strong>Sistemas de Recomendación:</strong> Motores que sugieren productos o contenidos dependen de consultas SQL de baja latencia para recuperar perfiles de usuario y catálogos de ítems en tiempo real.</li>
            </ul>
            <blockquote>La sinergia de IA y SQL habilita "aplicaciones inteligentes" que aprenden de los datos y interactúan de forma natural con los usuarios. [25]</blockquote>
        """
    },
    {
        "titulo": "5. Arquitectura de Integración Moderna",
        "contenido": """
            <h4>El "Modern Data Stack" para IA</h4>
            <p>Una arquitectura típica que integra estas tecnologías de forma escalable y eficiente se compone de las siguientes capas: [4, 5, 7, 9, 10]</p>
            <div class="table-container">
                <table>
                    <thead><tr><th>Capa de la Arquitectura</th><th>Función Principal</th><th>Tecnologías Ejemplo</th></tr></thead>
                    <tbody>
                        <tr>
                            <td><strong>Ingesta de Datos</strong></td>
                            <td>Recopilar datos de múltiples fuentes (APIs, bases de datos, eventos de streaming).</td>
                            <td>Fivetran, Airbyte, Kafka, AWS Kinesis</td>
                        </tr>
                        <tr>
                            <td><strong>Almacenamiento (Data Lake/Warehouse)</strong></td>
                            <td>Repositorio centralizado, escalable y flexible para datos crudos y transformados.</td>
                            <td>Snowflake, Google BigQuery, Databricks Lakehouse, Amazon Redshift</td>
                        </tr>
                        <tr>
                            <td><strong>Transformación de Datos</strong></td>
                            <td>Aplicar lógica de negocio y modelar los datos para el análisis (el corazón de SQL).</td>
                            <td>dbt (Data Build Tool), SQL</td>
                        </tr>
                        <tr>
                            <td><strong>Entrenamiento y Despliegue de IA/ML</strong></td>
                            <td>Construir, entrenar, versionar y servir modelos.</td>
                            <td>Vertex AI (Google), Amazon SageMaker, Azure ML, MLflow, PyTorch</td>
                        </tr>
                        <tr>
                            <td><strong>Orquestación y Monitoreo</strong></td>
                            <td>Automatizar, programar y monitorear la ejecución de todos los pipelines.</td>
                            <td>Airflow, Dagster, Prefect</td>
                        </tr>
                         <tr>
                            <td><strong>Capa de Consumo y Visualización</strong></td>
                            <td>Exponer los datos y las predicciones a los usuarios finales.</td>
                            <td>Tableau, Power BI, Looker, APIs (FastAPI), Streamlit</td>
                        </tr>
                    </tbody>
                </table>
            </div>
        """
    },
    {
        "titulo": "6. Casos de Uso Empresariales Estratégicos",
        "contenido": """
            <h4>Aplicaciones de Alto Impacto</h4>
            <p>La integración de SQL, ML e IA impulsa soluciones transformadoras en todos los sectores:</p>
            <ol>
                <li><strong>Detección de Fraude en Tiempo Real:</strong> Un pipeline de streaming usa SQL para enriquecer transacciones con datos históricos del cliente en milisegundos. Un modelo ML evalúa el riesgo y un sistema de IA decide si bloquear la transacción y generar una alerta.</li>
                <li><strong>Segmentación de Clientes Dinámica:</strong> Se ejecutan trabajos SQL nocturnos para recalcular features de comportamiento. Un modelo de clustering (ML) agrupa a los clientes en segmentos. Una campaña de marketing automatizada (IA) personaliza ofertas para cada segmento. [30]</li>
                <li><strong>Optimización de la Cadena de Suministro:</strong> Modelos de series temporales (ML) entrenados con datos históricos de ventas (extraídos con SQL) predicen la demanda futura. Un sistema de IA recomienda niveles de inventario óptimos para minimizar costos y evitar roturas de stock.</li>
                <li><strong>Asistente de Soporte al Cliente con RAG:</strong> Un cliente pregunta a un chatbot (IA) sobre el estado de su pedido. El agente RAG convierte la pregunta en una consulta SQL, busca en la base de datos de pedidos, y genera una respuesta precisa y personalizada. [17, 25]</li>
            </ol>
        """
    },
    {
        "titulo": "7. Seguridad y Gobernanza en el Ecosistema IA",
        "contenido": """
            <h4>Construyendo Confianza y Cumplimiento</h4>
            <p>A medida que los sistemas de IA se vuelven más autónomos, la gobernanza se vuelve crítica. SQL juega un rol central en asegurar un marco robusto y auditable. [1, 3]</p>
            <ul>
                <li><strong>Control de Acceso y Enmascaramiento:</strong> Las políticas de seguridad de la base de datos (roles y permisos SQL) aseguran que los modelos de ML solo accedan a los datos que necesitan (principio de mínimo privilegio). Técnicas de enmascaramiento dinámico pueden ofuscar datos sensibles.</li>
                <li><strong>Linaje de Datos y Auditoría:</strong> Es posible registrar cada consulta SQL usada para entrenar un modelo. Esto crea un linaje claro desde el dato crudo hasta la predicción, esencial para la depuración, la reproducibilidad y el cumplimiento de normativas como GDPR. [8]</li>
                <li><strong>Validación de Datos con SQL:</strong> Antes de entrenar o re-entrenar un modelo, se pueden ejecutar pruebas de calidad de datos escritas en SQL (ej: dbt tests) para detectar anomalías, nulos o derivas en los datos que podrían afectar negativamente al modelo.</li>
            </ul>
             <blockquote>Una buena gobernanza no es un obstáculo para la agilidad, sino un prerrequisito para escalar la IA de forma sostenible y responsable.</blockquote>
        """
    }
]

# --- LÓGICA DE GENERACIÓN (SIN CAMBIOS) ---
def generar_tarjetas_definiciones(datos):
    html_generado = []
    for seccion in datos:
        titulo_escapado = html.escape(seccion['titulo'])
        contenido_html = seccion['contenido']

        plantilla_seccion = f"""
        <div class="topic-card">
            <div class="topic-header">
                <span class="topic-title">{titulo_escapado}</span>
                <i class="fas fa-chevron-down expand-icon"></i>
            </div>
            <div class="topic-content">
                {contenido_html}
            </div>
        </div>
        """
        html_generado.append(plantilla_seccion)
    return "\n".join(html_generado)

# --- PRE-CÁLCULO DEL CONTENIDO DINÁMICO ---
contenido_dinamico_html = generar_tarjetas_definiciones(integration_data)

# --- PLANTILLA PROFESIONAL (SIN CAMBIOS) ---
plantilla_profesional = """
<!DOCTYPE html>
<html lang="es">
<head>
  <meta charset="UTF-8">
  <meta name="viewport" content="width=device-width, initial-scale=1.0">
  <title>{main_title}</title>
  <link href="https://fonts.googleapis.com/css2?family=Inter:wght@300;400;500;600;700;800&family=JetBrains+Mono:wght@400;500&display=swap" rel="stylesheet">
  <link href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.4.0/css/all.min.css" rel="stylesheet">
  <style>
    :root {{
      --bg-primary: linear-gradient(135deg, #0f2027 0%, #203a43 50%, #2c5364 100%);
      --bg-secondary: rgba(26, 32, 44, 0.85);
      --bg-tertiary: rgba(45, 55, 72, 0.7);
      --text-primary: #f7fafc;
      --text-secondary: #a0aec0;
      --text-light: #ffffff;
      --accent-primary: #1dd1a1;
      --accent-secondary: #48dbfb;
      --accent-gradient: linear-gradient(135deg, var(--accent-primary) 0%, var(--accent-secondary) 100%);
      --border-color: rgba(255, 255, 255, 0.15);
      --shadow-card: 0 15px 35px rgba(0, 0, 0, 0.1);
      --border-radius: 20px;
      --transition: all 0.4s cubic-bezier(0.25, 0.8, 0.25, 1);
    }}
    [data-theme="light"] {{
      --bg-primary: linear-gradient(135deg, #f5f7fa 0%, #c3cfe2 100%);
      --bg-secondary: rgba(255, 255, 255, 0.85);
      --bg-tertiary: rgba(248, 250, 252, 0.8);
      --text-primary: #2c3e50;
      --text-secondary: #34495e;
      --accent-primary: #3498db;
      --accent-secondary: #2ecc71;
      --border-color: rgba(226, 232, 240, 0.8);
    }}
    * {{ margin: 0; padding: 0; box-sizing: border-box; }}
    html {{ scroll-behavior: smooth; }}
    body {{ font-family: 'Inter', sans-serif; line-height: 1.8; background: var(--bg-primary); color: var(--text-primary); transition: var(--transition); min-height: 100vh; position: relative; overflow-x: hidden; }}
    .particles {{ position: fixed; top: 0; left: 0; width: 100%; height: 100%; pointer-events: none; z-index: -1; }}
    .particle {{ position: absolute; border-radius: 50%; animation: float 25s infinite linear; opacity: 0; background: rgba(255, 255, 255, 0.6);}}
    @keyframes float {{ 0% {{ transform: translateY(100vh) rotate(0deg); opacity: 0; }} 10%, 90% {{ opacity: 0.6; }} 100% {{ transform: translateY(-10vh) rotate(360deg); opacity: 0; }} }}

    .container {{ max-width: 1000px; margin: 0 auto; padding: 2rem; z-index: 1; }}
    .header {{ text-align: center; margin-bottom: 3rem; position: relative; }}
    .main-title {{ font-size: clamp(2.2rem, 5vw, 3.8rem); font-weight: 800; background: var(--accent-gradient); -webkit-background-clip: text; -webkit-text-fill-color: transparent; background-clip: text; margin-bottom: 1rem; }}

    .theme-toggle {{ position: fixed; top: 2rem; right: 2rem; width: 60px; height: 60px; border: 1px solid var(--border-color); border-radius: 50%; background: var(--bg-secondary); backdrop-filter: blur(15px); box-shadow: var(--shadow-card); cursor: pointer; display: flex; align-items: center; justify-content: center; font-size: 1.4rem; color: var(--accent-primary); transition: var(--transition); z-index: 1000; }}
    .theme-toggle:hover {{ transform: scale(1.15) rotate(180deg); }}

    .content-block {{
        background: var(--bg-secondary); backdrop-filter: blur(20px); border-radius: var(--border-radius);
        box-shadow: var(--shadow-card); border: 2px solid var(--border-color);
        padding: 2rem; margin-bottom: 2rem;
    }}
    .content-block h2 {{ color: var(--text-primary); margin-bottom: 1rem; }}
    .content-block p {{ color: var(--text-secondary); margin-bottom: 1rem; }}

    .lesson-container {{ display: flex; flex-direction: column; gap: 1.5rem; }}
    .topic-card {{ background: var(--bg-secondary); backdrop-filter: blur(20px); border-radius: var(--border-radius); box-shadow: var(--shadow-card); border: 2px solid var(--border-color); overflow: hidden; transition: var(--transition); }}
    .topic-header {{ cursor: pointer; padding: 1.5rem 2rem; display: flex; justify-content: space-between; align-items: center; }}
    .topic-title {{ font-size: 1.3rem; font-weight: 600; color: var(--text-primary); }}
    .expand-icon {{ font-size: 1.2rem; color: var(--text-secondary); transition: var(--transition); }}
    .topic-card.open .expand-icon {{ transform: rotate(180deg); color: var(--accent-primary); }}
    .topic-content {{ max-height: 0; overflow: hidden; transition: max-height 1.2s ease, padding 1.2s ease; background: var(--bg-tertiary); }}
    .topic-card.open .topic-content {{ max-height: 3500px; padding: 1.5rem 2rem; border-top: 1px solid var(--border-color); }}

    .topic-content h4 {{ color: var(--text-primary); margin-top: 1.5rem; margin-bottom: 0.5rem; font-size: 1.1rem; }}
    .topic-content p, .topic-content li {{ color: var(--text-secondary); line-height: 1.7; }}
    .topic-content ul, .topic-content ol {{ padding-left: 25px; margin-bottom: 1rem; }}
    .topic-content strong {{ color: var(--accent-primary); font-weight: 700; }}
    .topic-content blockquote {{
        border-left: 4px solid var(--accent-primary); padding-left: 1.5rem; margin: 1.5rem 0;
        font-style: italic; color: var(--text-secondary); background: rgba(127, 140, 141, 0.05);
        border-radius: 0 8px 8px 0; padding: 1rem 1.5rem;
    }}
    .table-container {{ overflow-x: auto; margin: 1.5rem 0; }}
    table {{ width: 100%; border-collapse: collapse; }}
    th, td {{ padding: 12px 15px; border: 1px solid var(--border-color); text-align: left; }}
    thead th {{ background-color: var(--bg-tertiary); color: var(--text-primary); font-weight: 600; }}
    tbody tr:nth-child(even) {{ background: rgba(127, 140, 141, 0.05); }}

    footer {{ text-align: center; margin-top: 4rem; padding-top: 2rem; border-top: 1px solid var(--border-color); }}
    footer p {{ color: var(--text-secondary); font-size: 0.9rem; opacity: 0.8; }}

    @media (max-width: 768px) {{
        .container {{ padding: 1rem; }}
        .topic-header {{ padding: 1rem 1.5rem; }}
        .topic-card.open .topic-content {{ padding: 1rem 1.5rem; }}
    }}
  </style>
</head>
<body data-theme="dark">
  <div class="particles" id="particles-container"></div>
  <div class="theme-toggle" id="themeToggleButton" title="Cambiar tema"><i class="fas fa-moon" id="theme-icon"></i></div>
  <div class="container">
    <header class="header">
      <h1 class="main-title">{main_title}</h1>
    </header>

    <div class="lesson-container">
        {dynamic_content_html}
    </div>

    {conclusion_html}

    <footer>
      <p>{footer_text}</p>
    </footer>
  </div>

  <script>
    (function() {{
        const themeToggleButton = document.getElementById('themeToggleButton');
        const themeIcon = document.getElementById('theme-icon');
        const bodyEl = document.body;

        function setTheme(theme) {{
            bodyEl.setAttribute('data-theme', theme);
            localStorage.setItem('theme', theme);
            if (themeIcon) {{ themeIcon.className = theme === 'dark' ? 'fas fa-sun' : 'fas fa-moon'; }}
        }}

        themeToggleButton.addEventListener('click', () => {{
            const newTheme = (bodyEl.getAttribute('data-theme') || 'dark') === 'light' ? 'light' : 'dark';
            setTheme(newTheme);
        }});

        // Aplica el tema guardado o el predeterminado al cargar
        setTheme(localStorage.getItem('theme') || 'dark');

        document.querySelectorAll('.topic-header').forEach(header => {{
            header.addEventListener('click', () => {{
                const card = header.parentElement;
                card.classList.toggle('open');
            }});
        }});

        const container = document.getElementById('particles-container');
        if (container) {{
            for (let i = 0; i < 30; i++) {{
                const p = document.createElement('div');
                p.className = 'particle';
                p.style.left = Math.random() * 100 + 'vw';
                const size = (Math.random() * 5 + 2);
                p.style.width = size + 'px';
                p.style.height = size + 'px';
                p.style.animationDelay = Math.random() * -20 + 's';
                p.style.animationDuration = (15 + Math.random() * 10) + 's';
                container.appendChild(p);
            }}
        }}

        const firstTopic = document.querySelector('.topic-card');
        if(firstTopic) {{
            firstTopic.classList.add('open');
        }}
    }})();
  </script>
</body>
</html>
"""

# --- INYECCIÓN DINÁMICA Y RENDERIZADO FINAL ---
final_html = plantilla_profesional.format(
    main_title="SQL, ML & AI: La Sinergia que Impulsa la Inteligencia de Negocio",
    dynamic_content_html=contenido_dinamico_html,
    conclusion_html=conclusion_html_block,
    footer_text="Elaborado por profesor Sergio Gevatschnaider."
)

display(HTML(final_html))
# Out:
# <!DOCTYPE html>
# <html lang="es">
# <head>
#   <meta charset="UTF-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1.0">
#   <title>SQL, ML & AI: La Sinergia que Impulsa la Inteligencia de Negocio</title>
#   <link href="https://fonts.googleapis.com/css2?family=Inter:wght@300;400;500;600;700;800&family=JetBrains+Mono:wght@400;500&display=swap" rel="stylesheet">
#   <link href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.4.0/css/all.min.css" rel="stylesheet">
#   <style>
#     :root {
#       --bg-primary: linear-gradient(135deg, #0f2027 0%, #203a43 50%, #2c5364 100%);
#       --bg-secondary: rgba(26, 32, 44, 0.85);
#       --bg-tertiary: rgba(45, 55, 72, 0.7);
#       --text-primary: #f7fafc;
#       --text-secondary: #a0aec0;
#       --text-light: #ffffff;
#       --accent-primary: #1dd1a1;
#       --accent-secondary: #48dbfb;
#       --accent-gradient: linear-gradient(135deg, var(--accent-primary) 0%, var(--accent-secondary) 100%);
# ...

# %%
# -*- coding: utf-8 -*-
# Importación de librerías necesarias
from IPython.display import display, HTML
import html # Para escapar caracteres especiales en los títulos

# --- 1. BLOQUES DE CONTENIDO AMPLIADO Y ENRIQUECIDO ---

# --- Bloque de Buenas Prácticas (Conclusión) ---
best_practices_html_block = """
<div class="content-block">
    <h2>Buenas Prácticas Transversales: El Sello del Profesional</h2>
    <p>Dominar la sintaxis es solo el primer paso. La verdadera maestría en SQL se demuestra aplicando principios que garantizan sistemas robustos, mantenibles y escalables.</p>
    <ul>
        <li><strong>Versionado como Código (Migration-as-Code):</strong> Utiliza herramientas como <strong>Flyway</strong> o <strong>Liquibase</strong> para versionar los cambios en el esquema de la base de datos (DDL). Trata tu esquema como tratas el código de tu aplicación.</li>
        <li><strong>Indexación Inteligente:</strong> Los índices aceleran las lecturas (<code>SELECT</code>) pero ralentizan las escrituras (<code>INSERT</code>, <code>UPDATE</code>). Añade índices solo en columnas frecuentemente usadas en cláusulas <code>WHERE</code>, <code>JOIN</code> y <code>ORDER BY</code>.</li>
        <li><strong>Transaccionalidad:</strong> Envuelve operaciones lógicas que involucran múltiples sentencias (ej. transferir dinero) en transacciones (<code>BEGIN...COMMIT/ROLLBACK</code>) para garantizar la atomicidad y la consistencia de los datos.</li>
        <li><strong>Documentación y Nomenclatura:</strong> Documenta cada tabla y columna con la cláusula <code>COMMENT ON</code>. Adopta y sigue una convención de nomenclatura estricta (ej. <code>snake_case</code> para todos los identificadores).</li>
        <li><strong>Optimización Basada en Evidencia:</strong> Nunca asumas que una consulta es lenta o rápida. Usa <code>EXPLAIN ANALYZE</code> para ver el plan de ejecución que el motor de base de datos elige. Esta es la herramienta fundamental para optimizar el rendimiento.</li>
        <li><strong>Uso de CTEs para Claridad:</strong> Utiliza <strong>Common Table Expressions</strong> (<code>WITH ... AS (...)</code>) para dividir consultas complejas en pasos lógicos y legibles, evitando subconsultas anidadas difíciles de seguir.</li>
    </ul>
</div>
"""

# --- Contenido Principal para el Acordeón (TEMA: GUÍA PROFUNDA DE SQL) ---
sql_concepts_data = [
    {
        "titulo": "1. Crear una Base de Datos (CREATE DATABASE)",
        "contenido": """
            <h4>Sintaxis y Consideraciones Clave</h4>
            <p>Este comando inicializa un nuevo espacio lógico para almacenar tablas y otros objetos. Su configuración inicial es crítica.</p>
            <div class="content-block" style="background-color: #2d2d2d; color: #f0f0f0; font-family: 'JetBrains Mono', monospace; padding: 1rem; border-radius: 8px;">
                <pre><code>-- Sintaxis robusta para PostgreSQL
CREATE DATABASE biblioteca
  WITH
    ENCODING = 'UTF8'
    LC_COLLATE = 'es_ES.UTF-8'  -- Reglas de ordenación para el español
    LC_CTYPE   = 'es_ES.UTF-8'  -- Reglas de clasificación de caracteres
    TEMPLATE   = template0;    -- Plantilla limpia sin objetos locales
</code></pre>
            </div>
            <ul>
                <li><code>IF NOT EXISTS</code> (MySQL/PostgreSQL > v9.6): Es una protección útil en scripts de aprovisionamiento para evitar errores si la base de datos ya existe.</li>
                <li><strong>Encoding & Collation</strong>: Definen el juego de caracteres y las reglas de ordenación. Una elección incorrecta al inicio puede causar problemas permanentes con acentos, caracteres especiales y en cláusulas <code>ORDER BY</code>. <code>UTF-8</code> es el estándar de facto.</li>
                <li><strong>Permisos</strong>: Inmediatamente después de crear una base de datos, es crucial asignar permisos. Por ejemplo: <code>GRANT ALL PRIVILEGES ON DATABASE biblioteca TO mi_usuario;</code>.</li>
            </ul>
        """
    },
    {
        "titulo": "2. Ver Bases de Datos Disponibles",
        "contenido": """
            <h4>Consultando el Catálogo del Servidor</h4>
            <p>Cada motor tiene su propio dialecto, pero el estándar ANSI proporciona una vía portable.</p>
            <div class="table-container">
                <table>
                    <thead><tr><th>Motor</th><th>Comando Estándar</th><th>Alternativa Nativa Interactiva</th></tr></thead>
                    <tbody>
                        <tr><td><strong>ANSI SQL (Portable)</strong></td><td><code>SELECT schema_name FROM information_schema.schemata;</code></td><td>—</td></tr>
                        <tr><td><strong>MySQL</strong></td><td><code>SHOW DATABASES;</code></td><td>—</td></tr>
                        <tr><td><strong>PostgreSQL</strong></td><td><code>SELECT datname FROM pg_database WHERE datistemplate = false;</code></td><td><code>\\l</code> en la consola <code>psql</code></td></tr>
                    </tbody>
                </table>
            </div>
            <blockquote><strong>Tip Profesional:</strong> En entornos compartidos (multi-tenant), filtra por propietario para ver solo tus bases de datos: <code>...WHERE pg_database.datdba = (SELECT usesysid FROM pg_user WHERE usename = 'mi_usuario')</code>.</blockquote>
        """
    },
    {
        "titulo": "3. Eliminar una Base de Datos (DROP DATABASE)",
        "contenido": """
            <h4>Un Comando Destructivo que Requiere Precaución</h4>
            <p>Esta operación es irreversible y elimina la base de datos y todos los objetos que contiene.</p>
            <div class="content-block" style="background-color: #2d2d2d; color: #f0f0f0; font-family: 'JetBrains Mono', monospace; padding: 1rem; border-radius: 8px;">
                <pre><code>-- Sintaxis segura
DROP DATABASE IF EXISTS biblioteca;

-- Forzar el borrado en PostgreSQL desconectando a los usuarios
ALTER DATABASE biblioteca CONNECTION LIMIT 0;
SELECT pg_terminate_backend(pid) FROM pg_stat_activity WHERE datname = 'biblioteca';
DROP DATABASE biblioteca;
</code></pre>
            </div>
            <ul>
                <li><strong><code>RESTRICT</code> vs. <code>CASCADE</code> (PostgreSQL)</strong>: Por defecto, <code>DROP</code> usa <code>RESTRICT</code>, que falla si hay conexiones activas. <code>CASCADE</code> es mucho más peligroso, ya que eliminaría objetos que dependen de esta base de datos, aunque su uso es raro.</li>
                <li><strong>Práctica recomendada:</strong> ¡SIEMPRE realiza una copia de seguridad (<code>pg_dump</code>, <code>mysqldump</code>) antes de ejecutar <code>DROP DATABASE</code> en un entorno que no sea de desarrollo local!</li>
            </ul>
        """
    },
    {
        "titulo": "4. Comentarios: Documentando el Esquema",
        "contenido": """
            <h4>Metadatos que Aportan Claridad</h4>
            <p>Los comentarios son una forma de documentación viva que se almacena junto al esquema de la base de datos.</p>
            <div class="content-block" style="background-color: #2d2d2d; color: #f0f0f0; font-family: 'JetBrains Mono', monospace; padding: 1rem; border-radius: 8px;">
                <pre><code>-- Comentario de una sola línea (no se almacena)

/*
  Comentario multilínea (tampoco se almacena)
*/

-- Comentarios que SÍ se almacenan en el catálogo del sistema:
COMMENT ON TABLE libros IS 'Almacena el catálogo de todos los títulos de la biblioteca.';
COMMENT ON COLUMN libros.isbn IS 'International Standard Book Number, identificador único de 13 dígitos.';
</code></pre>
            </div>
            <blockquote><strong>Impacto en el Ecosistema:</strong> Herramientas de <strong>Data Catalog</strong> (como Atlan, DataHub) y de documentación (como DataGrip, dbdocs.io) leen estos comentarios para generar automáticamente documentación de datos, promoviendo el gobierno de datos.</blockquote>
        """
    },
    {
        "titulo": "5. El Concepto de Tabla",
        "contenido": """
            <h4>La Unidad Fundamental de Almacenamiento</h4>
            <p>Una tabla es la estructura que materializa una "relación" en el modelo relacional. Organiza los datos en filas (tuplas) y columnas (atributos).</p>
            <ul>
                <li><strong>Fila (Tupla):</strong> Representa una única instancia de una entidad. Ej: un libro específico.</li>
                <li><strong>Columna (Atributo):</strong> Representa una propiedad de esa entidad, con un tipo de dato definido (su "dominio"). Ej: el título del libro.</li>
                <li><strong>Normalización vs. Desnormalización:</strong>
                    <ul>
                        <li><strong>Sistemas Transaccionales (OLTP):</strong> Se busca la normalización (generalmente hasta la 3FN o BCNF) para evitar redundancia y anomalías de datos (ej. una tienda online).</li>
                        <li><strong>Sistemas Analíticos (OLAP):</strong> A menudo se prefiere desnormalizar los datos en un <strong>Data Warehouse</strong> para acelerar consultas complejas de agregación y reportería.</li>
                    </ul>
                </li>
            </ul>
        """
    },
        {
        "titulo": "6. Tipos de Datos Esenciales",
        "contenido": """
            <h4>Definiendo el Dominio de Cada Atributo</h4>
            <p>Elegir el tipo de dato correcto es fundamental para la integridad de los datos, el rendimiento y el uso del almacenamiento.</p>
            <div class="table-container">
                <table>
                    <thead><tr><th>Categoría</th><th>Ejemplos Comunes</th><th>Caso de Uso Estratégico</th></tr></thead>
                    <tbody>
                        <tr><td><strong>Numéricos</strong></td><td><code>INT</code>, <code>BIGINT</code>, <code>NUMERIC(p, s)</code>, <code>FLOAT</code></td><td>Usa <code>NUMERIC</code> o <code>DECIMAL</code> para valores monetarios para evitar errores de redondeo. <code>BIGINT</code> para IDs en tablas muy grandes.</td></tr>
                        <tr><td><strong>Texto</strong></td><td><code>VARCHAR(n)</code>, <code>TEXT</code>, <code>CHAR(n)</code></td><td><code>VARCHAR(n)</code> es ideal para textos de longitud variable pero acotada. <code>TEXT</code> para longitudes indefinidas. <code>CHAR(n)</code> para códigos de longitud fija (ej. 'ES', 'MX').</td></tr>
                        <tr><td><strong>Fecha/Hora</strong></td><td><code>DATE</code>, <code>TIMESTAMP</code>, <code>TIMESTAMPTZ</code> (PostgreSQL)</td><td>Usa <code>TIMESTAMPTZ</code> (con zona horaria) para aplicaciones globales para asegurar que los instantes de tiempo son inequívocos.</td></tr>
                        <tr><td><strong>Booleanos</strong></td><td><code>BOOLEAN</code> (PostgreSQL), <code>TINYINT(1)</code> (MySQL)</td><td>Perfecto para flags (indicadores de verdadero/falso) como <code>is_active</code> o <code>is_deleted</code> (soft delete).</td></tr>
                        <tr><td><strong>Especializados</strong></td><td><code>JSONB</code>, <code>UUID</code>, <code>ARRAY</code>, <code>GEOMETRY</code></td><td><code>JSONB</code> (PostgreSQL) para datos semi-estructurados indexables. <code>UUID</code> como clave primaria en sistemas distribuidos para evitar colisiones.</td></tr>
                    </tbody>
                </table>
            </div>
        """
    },
    {
        "titulo": "7. Restricciones (Constraints)",
        "contenido": """
            <h4>Imponiendo Reglas de Negocio en la Base de Datos</h4>
            <p>Las restricciones son el mecanismo principal para garantizar la integridad y la calidad de los datos a nivel de la base de datos.</p>
             <div class="table-container">
                <table>
                    <thead><tr><th>Restricción</th><th>Propósito</th><th>Ejemplo de Sintaxis Moderna</th></tr></thead>
                    <tbody>
                        <tr><td><strong>PRIMARY KEY</strong></td><td>Identificador único e no nulo para cada fila.</td><td><code>id BIGINT PRIMARY KEY GENERATED ALWAYS AS IDENTITY</code></td></tr>
                        <tr><td><strong>UNIQUE</strong></td><td>Garantiza que todos los valores en la columna son únicos.</td><td><code>email VARCHAR(255) UNIQUE NOT NULL</code></td></tr>
                        <tr><td><strong>NOT NULL</strong></td><td>Asegura que la columna no puede contener valores <code>NULL</code>.</td><td><code>titulo VARCHAR(150) NOT NULL</code></td></tr>
                        <tr><td><strong>CHECK</strong></td><td>Valida que los valores cumplen una condición lógica.</td><td><code>CHECK (precio > 0 AND moneda IN ('USD', 'EUR'))</code></td></tr>
                        <tr><td><strong>DEFAULT</strong></td><td>Proporciona un valor por defecto si no se especifica uno.</td><td><code>fecha_creacion TIMESTAMPTZ DEFAULT CURRENT_TIMESTAMP</code></td></tr>
                        <tr><td><strong>FOREIGN KEY</strong></td><td>Crea una relación con otra tabla, garantizando la integridad referencial.</td><td><code>autor_id BIGINT REFERENCES autores(id) ON DELETE SET NULL</code></td></tr>
                    </tbody>
                </table>
            </div>
        """
    },
    {
        "titulo": "8. Crear una Tabla (CREATE TABLE)",
        "contenido": """
            <h4>Definiendo la Estructura de una Entidad</h4>
            <p>Este es uno de los comandos más importantes, donde se combinan columnas, tipos de datos y restricciones.</p>
            <div class="content-block" style="background-color: #2d2d2d; color: #f0f0f0; font-family: 'JetBrains Mono', monospace; padding: 1rem; border-radius: 8px;">
                <pre><code>CREATE TABLE IF NOT EXISTS libros (
    id            BIGINT        GENERATED ALWAYS AS IDENTITY, -- Sintaxis moderna autoincremental
    isbn          VARCHAR(13)   NOT NULL UNIQUE,
    titulo        VARCHAR(250)  NOT NULL,
    autor_id      BIGINT,
    precio        NUMERIC(10, 2) CHECK (precio >= 0),
    publicado_en  DATE,
    creado_en     TIMESTAMPTZ   DEFAULT now(),

    -- Definición de restricciones al final para mayor claridad
    CONSTRAINT pk_libros PRIMARY KEY (id),
    CONSTRAINT fk_libros_autores FOREIGN KEY (autor_id)
        REFERENCES autores(id)
        ON DELETE SET NULL -- Si se borra un autor, el libro no se borra, solo se desvincula
);
</code></pre>
            </div>
            <blockquote><strong>Particionamiento:</strong> Para tablas extremadamente grandes (miles de millones de filas), se puede añadir <code>PARTITION BY RANGE (publicado_en)</code> para dividir físicamente la tabla por año o mes, mejorando drásticamente el rendimiento de las consultas con filtros de fecha.</blockquote>
        """
    },
    {
        "titulo": "9. Ver la Estructura de una Tabla",
        "contenido": """
            <h4>Inspeccionando el Diseño de una Tabla</h4>
            <p>Esencial para desarrolladores y analistas para entender qué datos contiene una tabla y cómo están definidos.</p>
            <div class="table-container">
                <table>
                    <thead><tr><th>Motor</th><th>Comando Interactivo</th><th>Consulta Programática (ANSI)</th></tr></thead>
                    <tbody>
                        <tr><td><strong>MySQL</strong></td><td><code>DESCRIBE libros;</code> o <code>SHOW CREATE TABLE libros\\G</code></td><td rowspan="2"><code>SELECT column_name, data_type, is_nullable, column_default
FROM information_schema.columns
WHERE table_schema = 'public' AND table_name = 'libros';</code></td></tr>
                        <tr><td><strong>PostgreSQL</strong></td><td><code>\\d+ libros</code> (en psql)</td></tr>
                    </tbody>
                </table>
            </div>
            <p>La vista <code>information_schema</code> es la forma preferida de obtener metadatos en scripts y aplicaciones, ya que es estándar y su salida es consistente y fácil de procesar.</p>
        """
    },
    {
        "titulo": "10. Obtener Registros (SELECT)",
        "contenido": """
            <h4>La Esencia de la Consulta de Datos</h4>
            <p><code>SELECT</code> es el comando utilizado para leer y recuperar datos de una o más tablas.</p>
             <div class="content-block" style="background-color: #2d2d2d; color: #f0f0f0; font-family: 'JetBrains Mono', monospace; padding: 1rem; border-radius: 8px;">
                <pre><code>SELECT
    isbn,
    titulo,
    precio
FROM
    libros
WHERE
    publicado_en >= '2023-01-01'
    AND precio < 50.00;
</code></pre>
            </div>
            <blockquote><strong>Regla de Oro:</strong> Nunca uses <code>SELECT *</code> en código de producción. Especifica siempre las columnas que necesitas. Esto reduce el tráfico de red, usa menos memoria y hace que tu código sea resistente a cambios en el esquema de la tabla (si se añade o elimina una columna, tu aplicación no se romperá).</blockquote>
        """
    },
    {
        "titulo": "11. Literales: Valores Constantes",
        "contenido": """
            <h4>Representando Datos Fijos en tus Consultas</h4>
            <p>Un literal es un valor fijo que se escribe directamente en la consulta.</p>
            <ul>
                <li><strong>Cadena de Texto:</strong> <code>'El Quijote'</code>. Siempre entre comillas simples. Para incluir una comilla, duplícala: <code>'It''s a book'</code>.</li>
                <li><strong>Numérico:</strong> <code>100</code> (entero), <code>29.99</code> (decimal). No uses comillas.</li>
                <li><strong>Fecha/Hora (ANSI):</strong> <code>DATE '2025-07-16'</code>, <code>TIMESTAMP '2025-07-16 21:30:00'</code>. Usar el prefijo de tipo es la forma más explícita y portable.</li>
                <li><strong>Booleano:</strong> <code>TRUE</code>, <code>FALSE</code>.</li>
                <li><strong>Nulo:</strong> <code>NULL</code>. Representa la ausencia de valor. Ojo: <code>NULL</code> no es igual a nada, ni siquiera a otro <code>NULL</code>. Usa <code>IS NULL</code> o <code>IS NOT NULL</code> para comparaciones.</li>
            </ul>
        """
    },
    {
        "titulo": "12. Alias (AS): Renombrando Columnas y Tablas",
        "contenido": """
            <h4>Mejorando la Legibilidad y Claridad</h4>
            <p>Los alias se usan para dar nombres temporales a tablas o columnas durante la ejecución de una consulta.</p>
             <div class="content-block" style="background-color: #2d2d2d; color: #f0f0f0; font-family: 'JetBrains Mono', monospace; padding: 1rem; border-radius: 8px;">
                <pre><code>SELECT
    l.titulo        AS "Título del Libro", -- Alias de columna con espacios
    a.nombre_completo AS autor
FROM
    libros AS l
JOIN
    autores AS a ON l.autor_id = a.id;
</code></pre>
            </div>
            <ul>
                <li><strong>Alias de Tabla (<code>l</code>, <code>a</code>):</strong> Hacen las consultas con <code>JOIN</code>s mucho más cortas y legibles.</li>
                <li><strong>Alias de Columna (<code>"Título del Libro"</code>, <code>autor</code>):</strong> Permiten definir nombres de columna claros para la salida, lo cual es esencial para reportes, APIs y herramientas de BI. Se pueden reutilizar en <code>ORDER BY</code>.</li>
            </ul>
        """
    },
    {
        "titulo": "13. Ordenar Resultados (ORDER BY)",
        "contenido": """
            <h4>Controlando el Orden de las Filas de Salida</h4>
            <p><code>ORDER BY</code> determina la secuencia en la que se devuelven las filas.</p>
             <div class="content-block" style="background-color: #2d2d2d; color: #f0f0f0; font-family: 'JetBrains Mono', monospace; padding: 1rem; border-radius: 8px;">
                <pre><code>SELECT titulo, publicado_en, precio
FROM libros
ORDER BY publicado_en DESC, precio ASC NULLS LAST;
</code></pre>
            </div>
            <ul>
                <li><strong>Orden Múltiple:</strong> La consulta anterior ordena los libros del más reciente al más antiguo. Si dos libros tienen la misma fecha de publicación, se ordenan por precio, del más barato al más caro.</li>
                <li><strong><code>ASC</code> / <code>DESC</code>:</strong> Ascendente (por defecto) / Descendente.</li>
                <li><strong><code>NULLS FIRST</code> / <code>NULLS LAST</code>:</strong> Característica muy útil (en PostgreSQL, Oracle) para decidir explícitamente dónde aparecen los valores nulos en la ordenación.</li>
                <li><strong>Rendimiento:</strong> Un índice en las columnas de <code>ORDER BY</code> puede mejorar drásticamente el rendimiento al evitar una operación de ordenación costosa en memoria o disco.</li>
            </ul>
        """
    },
    {
        "titulo": "14. Limitar Resultados (LIMIT / FETCH)",
        "contenido": """
            <h4>Obteniendo un Subconjunto de Filas</h4>
            <p>Esencial para previsualizaciones, paginación y para evitar transferir resultados masivos.</p>
             <div class="table-container">
                <table>
                    <thead><tr><th>Sintaxis</th><th>Motores Comunes</th></tr></thead>
                    <tbody>
                        <tr><td><code>SELECT ... LIMIT 10;</code></td><td>MySQL, PostgreSQL, SQLite</td></tr>
                        <tr><td><code>SELECT TOP 10 ...;</code></td><td>SQL Server, Sybase</td></tr>
                        <tr><td><code>SELECT ... FETCH FIRST 10 ROWS ONLY;</code></td><td>Oracle 12c+, DB2, Estándar ANSI SQL:2008</td></tr>
                    </tbody>
                </table>
            </div>
            <blockquote><strong>Importante:</strong> Usa siempre <code>LIMIT</code> en conjunto con <code>ORDER BY</code>. Sin un <code>ORDER BY</code>, el conjunto de 10 filas que recibes no es determinista y podría cambiar entre ejecuciones.</blockquote>
        """
    },
    {
        "titulo": "15. Paginación: LIMIT con OFFSET vs. Keyset Pagination",
        "contenido": """
            <h4>Navegando a Través de Grandes Conjuntos de Resultados</h4>
            <p>La paginación es fundamental para las interfaces de usuario. Sin embargo, el método tradicional tiene problemas de rendimiento.</p>

            <h4>Método Tradicional (<code>OFFSET</code>) - ¡Lento en tablas grandes!</h4>
            <div class="content-block" style="background-color: #2d2d2d; color: #f0f0f0; font-family: 'JetBrains Mono', monospace; padding: 1rem; border-radius: 8px;">
                <pre><code>-- Para obtener la página 101 (filas 1000 a 1009)
SELECT id, titulo FROM libros ORDER BY id LIMIT 10 OFFSET 1000;
</code></pre>
            </div>
            <p><strong>El Problema:</strong> Para llegar al offset 1000, la base de datos todavía tiene que leer y descartar las primeras 1000 filas. Esto se vuelve extremadamente lento a medida que el número de página aumenta.</p>

            <h4>Método Escalable (Keyset Pagination / Seek Method) - ¡Rápido!</h4>
            <p>Esta técnica usa el valor de la última fila vista en la página anterior para "saltar" directamente al siguiente conjunto de resultados.</p>
             <div class="content-block" style="background-color: #2d2d2d; color: #f0f0f0; font-family: 'JetBrains Mono', monospace; padding: 1rem; border-radius: 8px;">
                <pre><code>-- Suponiendo que el último 'id' visto en la página anterior fue 987
SELECT id, titulo
FROM libros
WHERE id > 987  -- La clave es esta condición WHERE
ORDER BY id
LIMIT 10;
</code></pre>
            </div>
            <p>Este método es casi instantáneo sin importar en qué página estés, ya que utiliza un índice en la columna <code>id</code> para buscar directamente el punto de partida.</p>
        """
    }
]

# --- LÓGICA DE GENERACIÓN (SIN CAMBIOS) ---
def generar_tarjetas_definiciones(datos):
    html_generado = []
    for seccion in datos:
        titulo_escapado = html.escape(seccion['titulo'])
        contenido_html = seccion['contenido']

        plantilla_seccion = f"""
        <div class="topic-card">
            <div class="topic-header">
                <span class="topic-title">{titulo_escapado}</span>
                <i class="fas fa-chevron-down expand-icon"></i>
            </div>
            <div class="topic-content">
                {contenido_html}
            </div>
        </div>
        """
        html_generado.append(plantilla_seccion)
    return "\n".join(html_generado)

# --- PRE-CÁLCULO DEL CONTENIDO DINÁMICO ---
contenido_dinamico_html = generar_tarjetas_definiciones(sql_concepts_data)

# --- PLANTILLA PROFESIONAL (SIN CAMBIOS SIGNIFICATIVOS, SOLO TEMA PREDETERMINADO) ---
plantilla_profesional = """
<!DOCTYPE html>
<html lang="es">
<head>
  <meta charset="UTF-8">
  <meta name="viewport" content="width=device-width, initial-scale=1.0">
  <title>{main_title}</title>
  <link href="https://fonts.googleapis.com/css2?family=Inter:wght@300;400;500;600;700;800&family=JetBrains+Mono:wght@400;500&display=swap" rel="stylesheet">
  <link href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.4.0/css/all.min.css" rel="stylesheet">
  <style>
    :root {{
      --bg-primary: linear-gradient(135deg, #0f2027 0%, #203a43 50%, #2c5364 100%);
      --bg-secondary: rgba(26, 32, 44, 0.85);
      --bg-tertiary: rgba(45, 55, 72, 0.7);
      --text-primary: #f7fafc;
      --text-secondary: #a0aec0;
      --accent-primary: #1dd1a1;
      --accent-secondary: #48dbfb;
      --accent-gradient: linear-gradient(135deg, var(--accent-primary) 0%, var(--accent-secondary) 100%);
      --border-color: rgba(255, 255, 255, 0.15);
      --shadow-card: 0 15px 35px rgba(0, 0, 0, 0.1);
      --border-radius: 20px;
      --transition: all 0.4s cubic-bezier(0.25, 0.8, 0.25, 1);
    }}
    [data-theme="light"] {{
      --bg-primary: linear-gradient(135deg, #f5f7fa 0%, #c3cfe2 100%);
      --bg-secondary: rgba(255, 255, 255, 0.85);
      --bg-tertiary: rgba(248, 250, 252, 0.8);
      --text-primary: #2c3e50;
      --text-secondary: #34495e;
      --accent-primary: #3498db;
      --accent-secondary: #2ecc71;
      --border-color: rgba(226, 232, 240, 0.8);
    }}
    * {{ margin: 0; padding: 0; box-sizing: border-box; }}
    html {{ scroll-behavior: smooth; }}
    body {{ font-family: 'Inter', sans-serif; line-height: 1.8; background: var(--bg-primary); color: var(--text-primary); transition: var(--transition); min-height: 100vh; position: relative; overflow-x: hidden; }}
    .particles {{ position: fixed; top: 0; left: 0; width: 100%; height: 100%; pointer-events: none; z-index: -1; }}
    .particle {{ position: absolute; border-radius: 50%; animation: float 25s infinite linear; opacity: 0; background: rgba(255, 255, 255, 0.6);}}
    @keyframes float {{ 0% {{ transform: translateY(100vh) rotate(0deg); opacity: 0; }} 10%, 90% {{ opacity: 0.6; }} 100% {{ transform: translateY(-10vh) rotate(360deg); opacity: 0; }} }}

    .container {{ max-width: 1000px; margin: 0 auto; padding: 2rem; z-index: 1; }}
    .header {{ text-align: center; margin-bottom: 3rem; position: relative; }}
    .main-title {{ font-size: clamp(2.2rem, 5vw, 3.8rem); font-weight: 800; background: var(--accent-gradient); -webkit-background-clip: text; -webkit-text-fill-color: transparent; background-clip: text; margin-bottom: 1rem; }}

    .theme-toggle {{ position: fixed; top: 2rem; right: 2rem; width: 60px; height: 60px; border: 1px solid var(--border-color); border-radius: 50%; background: var(--bg-secondary); backdrop-filter: blur(15px); box-shadow: var(--shadow-card); cursor: pointer; display: flex; align-items: center; justify-content: center; font-size: 1.4rem; color: var(--accent-primary); transition: var(--transition); z-index: 1000; }}
    .theme-toggle:hover {{ transform: scale(1.15) rotate(180deg); }}

    .content-block {{
        background: var(--bg-secondary); backdrop-filter: blur(20px); border-radius: var(--border-radius);
        box-shadow: var(--shadow-card); border: 2px solid var(--border-color);
        padding: 2rem; margin-bottom: 2rem;
    }}
    .content-block h2 {{ color: var(--text-primary); margin-bottom: 1rem; }}
    .content-block p, .content-block li {{ color: var(--text-secondary); margin-bottom: 1rem; }}
    .content-block ul {{padding-left: 20px;}}

    .lesson-container {{ display: flex; flex-direction: column; gap: 1.5rem; }}
    .topic-card {{ background: var(--bg-secondary); backdrop-filter: blur(20px); border-radius: var(--border-radius); box-shadow: var(--shadow-card); border: 2px solid var(--border-color); overflow: hidden; transition: var(--transition); }}
    .topic-header {{ cursor: pointer; padding: 1.5rem 2rem; display: flex; justify-content: space-between; align-items: center; }}
    .topic-title {{ font-size: 1.3rem; font-weight: 600; color: var(--text-primary); }}
    .expand-icon {{ font-size: 1.2rem; color: var(--text-secondary); transition: var(--transition); }}
    .topic-card.open .expand-icon {{ transform: rotate(180deg); color: var(--accent-primary); }}
    .topic-content {{ max-height: 0; overflow: hidden; transition: max-height 1.2s ease, padding 1.2s ease; background: var(--bg-tertiary); }}
    .topic-card.open .topic-content {{ max-height: 4500px; padding: 1.5rem 2rem; border-top: 1px solid var(--border-color); }}

    .topic-content h4 {{ color: var(--text-primary); margin-top: 1.5rem; margin-bottom: 0.5rem; font-size: 1.1rem; }}
    .topic-content p, .topic-content li {{ color: var(--text-secondary); line-height: 1.7; }}
    .topic-content ul {{ padding-left: 25px; margin-bottom: 1rem; }}
    .topic-content strong {{ color: var(--accent-primary); font-weight: 700; }}
    .topic-content blockquote {{
        border-left: 4px solid var(--accent-primary); padding-left: 1.5rem; margin: 1.5rem 0;
        font-style: italic; color: var(--text-secondary); background: rgba(127, 140, 141, 0.05);
        border-radius: 0 8px 8px 0; padding: 1rem 1.5rem;
    }}
    .table-container {{ overflow-x: auto; margin: 1.5rem 0; }}
    table {{ width: 100%; border-collapse: collapse; }}
    th, td {{ padding: 12px 15px; border: 1px solid var(--border-color); text-align: left; }}
    thead th {{ background-color: var(--bg-tertiary); color: var(--text-primary); font-weight: 600; }}
    tbody tr:nth-child(even) {{ background: rgba(127, 140, 141, 0.05); }}

    footer {{ text-align: center; margin-top: 4rem; padding-top: 2rem; border-top: 1px solid var(--border-color); }}
    footer p {{ color: var(--text-secondary); font-size: 0.9rem; opacity: 0.8; }}
  </style>
</head>
<body data-theme="dark">
  <div class="particles" id="particles-container"></div>
  <div class="theme-toggle" id="themeToggleButton" title="Cambiar tema"><i class="fas fa-moon" id="theme-icon"></i></div>
  <div class="container">
    <header class="header">
      <h1 class="main-title">{main_title}</h1>
    </header>
    <div class="lesson-container">
        {dynamic_content_html}
    </div>
    {conclusion_html}
    <footer>
      <p>{footer_text}</p>
    </footer>
  </div>
  <script>
    (function() {{
        const themeToggleButton = document.getElementById('themeToggleButton');
        const themeIcon = document.getElementById('theme-icon');
        const bodyEl = document.body;
        function setTheme(theme) {{
            bodyEl.setAttribute('data-theme', theme);
            localStorage.setItem('theme', theme);
            if (themeIcon) {{ themeIcon.className = theme === 'dark' ? 'fas fa-sun' : 'fas fa-moon'; }}
        }}
        themeToggleButton.addEventListener('click', () => {{
            const newTheme = (bodyEl.getAttribute('data-theme') || 'dark') === 'light' ? 'light' : 'dark';
            setTheme(newTheme);
        }});
        setTheme(localStorage.getItem('theme') || 'dark');
        document.querySelectorAll('.topic-header').forEach(header => {{
            header.addEventListener('click', () => {{
                header.parentElement.classList.toggle('open');
            }});
        }});
        const container = document.getElementById('particles-container');
        if (container) {{ for (let i = 0; i < 30; i++) {{ const p = document.createElement('div'); p.className = 'particle'; p.style.left = Math.random() * 100 + 'vw'; const size = (Math.random() * 5 + 2); p.style.width = size + 'px'; p.style.height = size + 'px'; p.style.animationDelay = Math.random() * -20 + 's'; p.style.animationDuration = (15 + Math.random() * 10) + 's'; container.appendChild(p); }} }}
        const firstTopic = document.querySelector('.topic-card');
        if(firstTopic) {{ firstTopic.classList.add('open'); }}
    }})();
  </script>
</body>
</html>
"""

# --- INYECCIÓN DINÁMICA Y RENDERIZADO FINAL ---
final_html = plantilla_profesional.format(
    main_title="Guía Definitiva de Conceptos SQL para Profesionales",
    dynamic_content_html=contenido_dinamico_html,
    conclusion_html=best_practices_html_block,
    footer_text="Elaborado por profesor Sergio Gevatschnaider."
)

display(HTML(final_html))
# Out:
# <!DOCTYPE html>
# <html lang="es">
# <head>
#   <meta charset="UTF-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1.0">
#   <title>Guía Definitiva de Conceptos SQL para Profesionales</title>
#   <link href="https://fonts.googleapis.com/css2?family=Inter:wght@300;400;500;600;700;800&family=JetBrains+Mono:wght@400;500&display=swap" rel="stylesheet">
#   <link href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.4.0/css/all.min.css" rel="stylesheet">
#   <style>
#     :root {
#       --bg-primary: linear-gradient(135deg, #0f2027 0%, #203a43 50%, #2c5364 100%);
#       --bg-secondary: rgba(26, 32, 44, 0.85);
#       --bg-tertiary: rgba(45, 55, 72, 0.7);
#       --text-primary: #f7fafc;
#       --text-secondary: #a0aec0;
#       --accent-primary: #1dd1a1;
#       --accent-secondary: #48dbfb;
#       --accent-gradient: linear-gradient(135deg, var(--accent-primary) 0%, var(--accent-secondary) 100%);
#       --border-color: rgba(255, 255, 255, 0.15);
# ...

# %%
# -*- coding: utf-8 -*-
# Importación de librerías necesarias
from IPython.display import display, HTML
import html # Para escapar caracteres especiales en los títulos

# --- 1. BLOQUES DE CONTENIDO AMPLIADO Y ENRIQUECIDO ---

# --- Bloque de Conclusión ---
conclusion_html_block = """
<div class="content-block">
    <h2>Conclusión: La Seguridad como Estrategia Integral</h2>
    <p>Una estrategia de seguridad de bases de datos efectiva trasciende la simple corrección de vulnerabilidades. Debe ser un enfoque holístico que considere todo el ciclo de vida del dato: desde su creación y transmisión hasta su almacenamiento, uso y eventual destrucción. La defensa en profundidad, que combina capas de seguridad a nivel de red, aplicación, base de datos y operaciones, es el único camino viable para proteger los activos de información críticos.</p>
    <p>La adopción de prácticas como las <strong>consultas parametrizadas</strong>, el <strong>principio de mínimo privilegio</strong> y el <strong>hashing robusto de credenciales</strong> no son opcionales, sino la base sobre la que se construye un sistema de datos seguro y confiable.</p>
</div>
"""

# --- Contenido Principal para el Acordeón (TEMA: SEGURIDAD EN BASES DE DATOS SQL) ---
sql_security_data = [
    {
        "titulo": "1. El Riesgo #1: Inyección SQL (SQLi)",
        "contenido": """
            <h4>¿Qué es?</h4>
            <p>La inyección SQL es una de las vulnerabilidades más antiguas y peligrosas. Ocurre cuando un atacante inserta código SQL malicioso dentro de una consulta legítima, explotando una validación de entradas deficiente por parte de la aplicación. Esto permite al atacante manipular la base de datos a su antojo.</p>

            <h4>Anatomía de un Ataque</h4>
            <p>Imaginemos una consulta vulnerable que concatena directamente las entradas del usuario:</p>
            <div class="content-block" style="background-color: #2d2d2d; color: #f0f0f0; font-family: 'JetBrains Mono', monospace; padding: 1rem; border-radius: 8px;">
                <pre><code>query = f"SELECT * FROM usuarios WHERE user = '{username}' AND pass = '{password}';"</code></pre>
            </div>
            <p>Si un atacante introduce <code>' OR '1'='1</code> como nombre de usuario, la consulta final se transforma:</p>
            <div class="content-block" style="background-color: #2d2d2d; color: #f0f0f0; font-family: 'JetBrains Mono', monospace; padding: 1rem; border-radius: 8px;">
                <pre><code>SELECT * FROM usuarios WHERE user = '' OR '1'='1' AND pass = '...';</code></pre>
            </div>
            <p>Dado que <code>'1'='1'</code> siempre es verdadero, la cláusula <code>WHERE</code> se cumple y el atacante obtiene acceso sin una contraseña válida.</p>

            <h4>La Solución Definitiva: Consultas Parametrizadas</h4>
            <p>Con las consultas preparadas (o parametrizadas), el código SQL y los datos del usuario viajan por separado. El motor de la base de datos compila la consulta primero y luego inserta los datos de forma segura, tratándolos siempre como valores literales, nunca como código ejecutable.</p>
            <p><strong>Ejemplo en Python (usando <code>psycopg2</code> para PostgreSQL):</strong></p>
            <div class="content-block" style="background-color: #2d2d2d; color: #f0f0f0; font-family: 'JetBrains Mono', monospace; padding: 1rem; border-radius: 8px;">
<pre><code>import psycopg2

# Datos provenientes de un formulario (potencialmente maliciosos)
user_input = "' OR '1'='1'"
pass_input = "password_cualquiera"

# CONEXIÓN SEGURA
conn = psycopg2.connect(...)
cur = conn.cursor()

# El SQL tiene placeholders (%s), no valores directos
sql_seguro = "SELECT * FROM usuarios WHERE user = %s AND pass = %s;"

# Los datos se pasan como un segundo argumento al método execute
# La librería se encarga de escaparlos y tratarlos de forma segura
cur.execute(sql_seguro, (user_input, pass_input))

# El intento de inyección falla. La consulta busca literalmente un usuario llamado "' OR '1'='1'".
</code></pre>
            </div>
        """
    },
    {
        "titulo": "2. Vulnerabilidades Críticas y Contramedidas",
        "contenido": """
            <p>Más allá de la inyección SQL, existen múltiples vectores de ataque que deben ser mitigados.</p>
            <div class="table-container">
                <table>
                    <thead><tr><th>Vulnerabilidad</th><th>Descripción del Riesgo</th><th>Mejor Práctica (Contramedida)</th></tr></thead>
                    <tbody>
                        <tr>
                            <td><strong>Exposición de Credenciales</strong></td>
                            <td>Almacenar contraseñas en texto plano o con algoritmos de hash débiles (ej. MD5, SHA1) permite a un atacante que acceda a la tabla autenticarse como cualquier usuario.</td>
                            <td>Usar algoritmos de hashing <strong>lentos y adaptativos</strong> como <strong>Argon2</strong> o <strong>bcrypt</strong>, siempre con una <strong>sal (salt)</strong> única por cada usuario.</td>
                        </tr>
                        <tr>
                            <td><strong>Permisos Excesivos</strong></td>
                            <td>Asignar a la cuenta de la aplicación permisos de administrador (<code>DBA</code>, <code>sa</code>) o <code>GRANT ALL</code>. Si la aplicación es comprometida, el atacante tiene control total.</td>
                            <td>Aplicar el <strong>Principio de Mínimo Privilegio (PoLP)</strong>. Crear roles específicos (ej. <code>rol_lectura</code>, <code>rol_escritura</code>) y asignar solo los permisos estrictamente necesarios sobre tablas específicas.</td>
                        </tr>
                        <tr>
                            <td><strong>Fugas de Información por Errores</strong></td>
                            <td>Mostrar trazas de error detalladas (stack traces) en producción puede revelar versiones de software, nombres de tablas, columnas y la estructura interna de las consultas.</td>
                            <td>Configurar la aplicación para que en producción capture los errores detallados en logs internos, pero muestre al usuario un mensaje de error genérico y un código de referencia.</td>
                        </tr>
                        <tr>
                            <td><strong>Acceso a Funciones Peligrosas</strong></td>
                            <td>Funciones como <code>xp_cmdshell</code> (SQL Server) o <code>dblink</code> (PostgreSQL) pueden permitir la ejecución de comandos del sistema operativo o el acceso a otras bases de datos.</td>
                            <td>Deshabilitar estas funciones si no son absolutamente necesarias. Si se usan, restringir su ejecución a roles de superusuario altamente controlados.</td>
                        </tr>
                    </tbody>
                </table>
            </div>
        """
    },
    {
        "titulo": "3. Framework de Defensa en Profundidad",
        "contenido": """
            <p>Una estrategia de seguridad robusta no depende de una única medida, sino de múltiples capas de defensa que trabajan en conjunto.</p>

            <h4>Capa 1: Red y Perímetro</h4>
            <ul>
                <li><strong>Segmentación de Red:</strong> Aislar la base de datos en una subred privada, inaccesible directamente desde internet. Solo los servidores de aplicación autorizados deben poder conectarse.</li>
                <li><strong>Firewall (ACLs):</strong> Configurar reglas de firewall para permitir conexiones al puerto de la base de datos (ej. 5432 para PostgreSQL) únicamente desde las direcciones IP de los servidores de aplicación.</li>
                <li><strong>Firewall de Aplicaciones Web (WAF):</strong> Colocar un WAF delante de la aplicación para detectar y bloquear patrones de ataque comunes, incluyendo muchos tipos de inyección SQL.</li>
            </ul>

            <h4>Capa 2: Conexión y Transmisión</h4>
            <ul>
                <li><strong>Cifrado en Tránsito:</strong> Forzar el uso de conexiones cifradas con TLS/SSL. Esto previene que un atacante en la red pueda espiar ("sniffing") los datos que viajan entre la aplicación y la base de datos.</li>
            </ul>

            <h4>Capa 3: Base de Datos y Almacenamiento</h4>
            <ul>
                <li><strong>Actualizaciones y Parches:</strong> Mantener el motor de la base de datos y el sistema operativo siempre actualizados con los últimos parches de seguridad.</li>
                <li><strong>Cifrado en Reposo (TDE):</strong> Utilizar Transparent Data Encryption (o cifrado a nivel de filesystem) para que los archivos de datos y los backups estén cifrados en el disco.</li>
                <li><strong>Auditoría y Monitoreo:</strong> Habilitar logs de auditoría para registrar accesos, consultas DDL (<code>CREATE</code>, <code>ALTER</code>, <code>DROP</code>) y fallos de autenticación. Enviar estos logs a un sistema centralizado (SIEM) para detectar anomalías.</li>
            </ul>

            <h4>Capa 4: Datos y Aplicación</h4>
            <ul>
                <li><strong>Control de Acceso Granular:</strong> Usar roles y políticas (incluyendo Row-Level Security si es necesario) para controlar el acceso a los datos de forma precisa.</li>
                <li><strong>Validación de Entradas:</strong> La aplicación debe validar siempre el tipo, longitud y formato de todas las entradas del usuario antes de procesarlas.</li>
                <li><strong>Gestión de Secretos:</strong> No escribir credenciales de base de datos en el código. Usar un gestor de secretos (como HashiCorp Vault o AWS Secrets Manager) o variables de entorno seguras.</li>
            </ul>
        """
    }
]


# --- LÓGICA DE GENERACIÓN (SIN CAMBIOS) ---
def generar_tarjetas_definiciones(datos):
    html_generado = []
    for seccion in datos:
        titulo_escapado = html.escape(seccion['titulo'])
        contenido_html = seccion['contenido']
        plantilla_seccion = f"""
        <div class="topic-card">
            <div class="topic-header">
                <span class="topic-title">{titulo_escapado}</span>
                <i class="fas fa-chevron-down expand-icon"></i>
            </div>
            <div class="topic-content">
                {contenido_html}
            </div>
        </div>
        """
        html_generado.append(plantilla_seccion)
    return "\n".join(html_generado)

# --- PRE-CÁLCULO DEL CONTENIDO DINÁMICO ---
contenido_dinamico_html = generar_tarjetas_definiciones(sql_security_data)

# --- PLANTILLA PROFESIONAL (CON PALETA DE COLORES DE SEGURIDAD) ---
plantilla_profesional = """
<!DOCTYPE html>
<html lang="es">
<head>
  <meta charset="UTF-8">
  <meta name="viewport" content="width=device-width, initial-scale=1.0">
  <title>{main_title}</title>
  <link href="https://fonts.googleapis.com/css2?family=Inter:wght@300;400;500;600;700;800&family=JetBrains+Mono:wght@400;500&display=swap" rel="stylesheet">
  <link href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.4.0/css/all.min.css" rel="stylesheet">
  <style>
    :root {{
      --bg-primary: linear-gradient(135deg, #141e30 0%, #243b55 100%);
      --bg-secondary: rgba(26, 32, 44, 0.85);
      --bg-tertiary: rgba(45, 55, 72, 0.7);
      --text-primary: #f7fafc;
      --text-secondary: #a0aec0;
      --accent-primary: #e74c3c;
      --accent-secondary: #c0392b;
      --accent-gradient: linear-gradient(135deg, var(--accent-primary) 0%, var(--accent-secondary) 100%);
      --border-color: rgba(255, 255, 255, 0.15);
      --shadow-card: 0 15px 35px rgba(0, 0, 0, 0.1);
      --border-radius: 20px;
      --transition: all 0.4s cubic-bezier(0.25, 0.8, 0.25, 1);
    }}
    [data-theme="light"] {{
      --bg-primary: linear-gradient(135deg, #ece9e6 0%, #ffffff 100%);
      --bg-secondary: rgba(255, 255, 255, 0.85);
      --bg-tertiary: rgba(248, 250, 252, 0.8);
      --text-primary: #2c3e50;
      --text-secondary: #34495e;
      --accent-primary: #d63031;
      --accent-secondary: #b71540;
      --border-color: rgba(226, 232, 240, 0.8);
    }}
    * {{ margin: 0; padding: 0; box-sizing: border-box; }}
    html {{ scroll-behavior: smooth; }}
    body {{ font-family: 'Inter', sans-serif; line-height: 1.8; background: var(--bg-primary); color: var(--text-primary); transition: var(--transition); min-height: 100vh; position: relative; overflow-x: hidden; }}
    .particles {{ position: fixed; top: 0; left: 0; width: 100%; height: 100%; pointer-events: none; z-index: -1; }}
    .particle {{ position: absolute; border-radius: 50%; animation: float 25s infinite linear; opacity: 0; background: rgba(255, 255, 255, 0.6);}}
    @keyframes float {{ 0% {{ transform: translateY(100vh) rotate(0deg); opacity: 0; }} 10%, 90% {{ opacity: 0.6; }} 100% {{ transform: translateY(-10vh) rotate(360deg); opacity: 0; }} }}

    .container {{ max-width: 1000px; margin: 0 auto; padding: 2rem; z-index: 1; }}
    .header {{ text-align: center; margin-bottom: 3rem; position: relative; }}
    .main-title {{ font-size: clamp(2.2rem, 5vw, 3.8rem); font-weight: 800; background: var(--accent-gradient); -webkit-background-clip: text; -webkit-text-fill-color: transparent; background-clip: text; margin-bottom: 1rem; }}

    .theme-toggle {{ position: fixed; top: 2rem; right: 2rem; width: 60px; height: 60px; border: 1px solid var(--border-color); border-radius: 50%; background: var(--bg-secondary); backdrop-filter: blur(15px); box-shadow: var(--shadow-card); cursor: pointer; display: flex; align-items: center; justify-content: center; font-size: 1.4rem; color: var(--accent-primary); transition: var(--transition); z-index: 1000; }}
    .theme-toggle:hover {{ transform: scale(1.15) rotate(180deg); }}

    .content-block {{
        background: var(--bg-secondary); backdrop-filter: blur(20px); border-radius: var(--border-radius);
        box-shadow: var(--shadow-card); border: 2px solid var(--border-color);
        padding: 2rem; margin-bottom: 2rem;
    }}
    .content-block h2 {{ color: var(--text-primary); margin-bottom: 1rem; }}
    .content-block p, .content-block li {{ color: var(--text-secondary); margin-bottom: 1rem; }}
    .content-block ul {{padding-left: 20px;}}

    .lesson-container {{ display: flex; flex-direction: column; gap: 1.5rem; }}
    .topic-card {{ background: var(--bg-secondary); backdrop-filter: blur(20px); border-radius: var(--border-radius); box-shadow: var(--shadow-card); border: 2px solid var(--border-color); overflow: hidden; transition: var(--transition); }}
    .topic-header {{ cursor: pointer; padding: 1.5rem 2rem; display: flex; justify-content: space-between; align-items: center; }}
    .topic-title {{ font-size: 1.3rem; font-weight: 600; color: var(--text-primary); }}
    .expand-icon {{ font-size: 1.2rem; color: var(--text-secondary); transition: var(--transition); }}
    .topic-card.open .expand-icon {{ transform: rotate(180deg); color: var(--accent-primary); }}
    .topic-content {{ max-height: 0; overflow: hidden; transition: max-height 2.5s ease-in-out, padding 2.5s ease-in-out; background: var(--bg-tertiary); }}
    .topic-card.open .topic-content {{ max-height: 6500px; padding: 1.5rem 2rem; border-top: 1px solid var(--border-color); }}

    .topic-content h4 {{ color: var(--text-primary); margin-top: 1.5rem; margin-bottom: 0.5rem; font-size: 1.1rem; }}
    .topic-content p, .topic-content li {{ color: var(--text-secondary); line-height: 1.7; }}
    .topic-content ul {{ padding-left: 25px; margin-bottom: 1rem; }}
    .topic-content strong {{ color: var(--accent-primary); font-weight: 700; }}
    .table-container {{ overflow-x: auto; margin: 1.5rem 0; }}
    table {{ width: 100%; border-collapse: collapse; }}
    th, td {{ padding: 12px 15px; border: 1px solid var(--border-color); text-align: left; }}
    thead th {{ background-color: var(--bg-tertiary); color: var(--text-primary); font-weight: 600; }}
    tbody tr:nth-child(even) {{ background: rgba(127, 140, 141, 0.05); }}

    footer {{ text-align: center; margin-top: 4rem; padding-top: 2rem; border-top: 1px solid var(--border-color); }}
    footer p {{ color: var(--text-secondary); font-size: 0.9rem; opacity: 0.8; }}
  </style>
</head>
<body data-theme="dark">
  <div class="particles" id="particles-container"></div>
  <div class="theme-toggle" id="themeToggleButton" title="Cambiar tema"><i class="fas fa-moon" id="theme-icon"></i></div>
  <div class="container">
    <header class="header">
      <h1 class="main-title">{main_title}</h1>
    </header>
    <div class="lesson-container">
        {dynamic_content_html}
    </div>
    {conclusion_html}
    <footer>
      <p>{footer_text}</p>
    </footer>
  </div>
  <script>
    (function() {{
        const themeToggleButton = document.getElementById('themeToggleButton');
        const themeIcon = document.getElementById('theme-icon');
        const bodyEl = document.body;
        function setTheme(theme) {{
            bodyEl.setAttribute('data-theme', theme);
            localStorage.setItem('theme', theme);
            if (themeIcon) {{ themeIcon.className = theme === 'dark' ? 'fas fa-sun' : 'fas fa-moon'; }}
        }}
        themeToggleButton.addEventListener('click', () => {{
            const newTheme = (bodyEl.getAttribute('data-theme') || 'dark') === 'light' ? 'light' : 'dark';
            setTheme(newTheme);
        }});
        setTheme(localStorage.getItem('theme') || 'dark');
        document.querySelectorAll('.topic-header').forEach(header => {{
            header.addEventListener('click', () => {{
                header.parentElement.classList.toggle('open');
            }});
        }});
        const container = document.getElementById('particles-container');
        if (container) {{ for (let i = 0; i < 30; i++) {{ const p = document.createElement('div'); p.className = 'particle'; p.style.left = Math.random() * 100 + 'vw'; const size = (Math.random() * 5 + 2); p.style.width = size + 'px'; p.style.height = size + 'px'; p.style.animationDelay = Math.random() * -20 + 's'; p.style.animationDuration = (15 + Math.random() * 10) + 's'; container.appendChild(p); }} }}
        const firstTopic = document.querySelector('.topic-card');
        if(firstTopic) {{ firstTopic.classList.add('open'); }}
    }})();
  </script>
</body>
</html>
"""

# --- INYECCIÓN DINÁMICA Y RENDERIZADO FINAL ---
final_html = plantilla_profesional.format(
    main_title="Seguridad en Bases de Datos SQL: Guía Esencial de Riesgos y Defensa",
    dynamic_content_html=contenido_dinamico_html,
    conclusion_html=conclusion_html_block,
    footer_text="Elaborado por profesor Sergio Gevatschnaider"
)

display(HTML(final_html))
# Out:
# <!DOCTYPE html>
# <html lang="es">
# <head>
#   <meta charset="UTF-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1.0">
#   <title>Seguridad en Bases de Datos SQL: Guía Esencial de Riesgos y Defensa</title>
#   <link href="https://fonts.googleapis.com/css2?family=Inter:wght@300;400;500;600;700;800&family=JetBrains+Mono:wght@400;500&display=swap" rel="stylesheet">
#   <link href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.4.0/css/all.min.css" rel="stylesheet">
#   <style>
#     :root {
#       --bg-primary: linear-gradient(135deg, #141e30 0%, #243b55 100%);
#       --bg-secondary: rgba(26, 32, 44, 0.85);
#       --bg-tertiary: rgba(45, 55, 72, 0.7);
#       --text-primary: #f7fafc;
#       --text-secondary: #a0aec0;
#       --accent-primary: #e74c3c;
#       --accent-secondary: #c0392b;
#       --accent-gradient: linear-gradient(135deg, var(--accent-primary) 0%, var(--accent-secondary) 100%);
#       --border-color: rgba(255, 255, 255, 0.15);
# ...

# %%
# -*- coding: utf-8 -*-
# Importación de librerías necesarias
from IPython.display import display, HTML
import html # Para escapar caracteres especiales en los títulos

# --- 1. BLOQUES DE CONTENIDO AMPLIADO Y ENRIQUECIDO ---

# --- Bloque de Conclusión ---
conclusion_html_block = """
<div class="content-block">
    <h2>Conclusión: La Seguridad como Proceso Continuo</h2>
    <p>La seguridad en SQL ha evolucionado de un simple conjunto de contramedidas a una filosofía integral de <strong>defensa en profundidad</strong>. Ya no basta con parametrizar consultas; es imperativo adoptar un modelo de <strong>Confianza Cero (Zero-Trust)</strong> que abarque el cifrado en todas sus formas, el hashing robusto de credenciales, un control de acceso granular y una auditoría proactiva y constante. [4, 5]</p>
    <p>Las funciones hash son una herramienta táctica esencial para proteger la confidencialidad (contraseñas) y la integridad (firmas de datos). Sin embargo, su verdadera eficacia reside en una implementación estratégica que incluya algoritmos modernos resistentes a la fuerza bruta (como <strong>Argon2</strong>), el uso sistemático de sales y una gestión segura de secretos (peppers, claves) fuera de la base de datos, preferiblemente en un <strong>HSM</strong> o <strong>KMS</strong>. [1, 3] Aplicar estas prácticas no es una opción, sino un requisito para construir sistemas de datos resilientes, confiables y seguros en el panorama de amenazas actual.</p>
</div>
"""

# --- Contenido Principal para el Acordeón (TEMA: SEGURIDAD SQL Y HASHING) ---
security_concepts_data = [
    {
        "titulo": "1. Contexto: El Modelo de Confianza Cero (Zero-Trust)",
        "contenido": """
            <h4>Filosofía Fundamental</h4>
            <p>El paradigma moderno de seguridad abandona la idea de un "perímetro seguro". En su lugar, el modelo de <strong>Confianza Cero</strong> asume que las amenazas pueden originarse tanto dentro como fuera de la red. Su lema es: <strong>"Nunca confíes, siempre verifica"</strong>. Esto implica que cada solicitud, cada conexión y cada acceso a datos debe ser autenticado y autorizado rigurosamente, sin importar su origen.</p>
            <h4>Superficie de Ataque en Bases de Datos</h4>
            <div class="table-container">
                <table>
                    <thead><tr><th>Amenaza Común</th><th>Ejemplo de Ataque</th><th>Mitigación Principal</th></tr></thead>
                    <tbody>
                        <tr><td><strong>Inyección SQL</strong></td><td><code>' OR '1'='1'; --</code></td><td><strong>Sentencias Preparadas (Parameterized Queries)</strong> y ORMs seguros.</td></tr>
                        <tr><td><strong>Escalada de Privilegios</strong></td><td>Un rol de aplicación con permisos de <code>DBA</code>.</td><td>Principio de Mínimo Privilegio (PoLP): roles específicos para cada tarea.</td></tr>
                        <tr><td><strong>Exfiltración de Datos</strong></td><td>Acceso a un backup de la base de datos sin cifrar.</td><td>Cifrado en reposo (TDE) y en tránsito (TLS 1.3).</td></tr>
                        <tr><td><strong>Manipulación de Registros</strong></td><td>Un <code>UPDATE</code> no autorizado que altera un saldo.</td><td>Auditoría detallada y políticas de Seguridad a Nivel de Fila (RLS).</td></tr>
                    </tbody>
                </table>
        """
    },
    {
        "titulo": "2. Hardening: Fortificación en Capas (Defensa en Profundidad)",
        "contenido": """
            <h4>Estrategia Multicapa</h4>
            <p>El hardening o "endurecimiento" consiste en aplicar medidas de seguridad en todas las capas del sistema para reducir la superficie de ataque.</p>
            <div class="table-container">
                 <table>
                    <thead><tr><th>Capa</th><th>Medidas Recomendadas</th><th>Por qué es Crítico</th></tr></thead>
                    <tbody>
                        <tr><td><strong>Red</strong></td><td>Segmentación (VPCs, subredes), Firewalls (ACLs), túneles VPN/SSH, forzar TLS 1.3.</td><td>Aísla la base de datos del acceso público y previene el espionaje de datos en la red.</td></tr>
                        <tr><td><strong>Servidor (OS)</strong></td><td>Parches de seguridad automáticos, deshabilitar servicios no usados, SELinux/AppArmor.</td><td>Reduce las vulnerabilidades a nivel de sistema operativo que podrían ser explotadas para acceder a la BD.</td></tr>
                        <tr><td><strong>Motor SQL</strong></td><td>Deshabilitar cuentas por defecto, rotación de contraseñas, MFA, cifrado nativo (TDE).</td><td>Fortalece el propio motor de la base de datos contra accesos no autorizados.</td></tr>
                        <tr><td><strong>Esquema y Roles</strong></td><td>Roles granulares (lectura, escritura), <code>GRANT</code> específico, Row-Level Security (RLS).</td><td>Garantiza que incluso los usuarios legítimos solo puedan ver y modificar los datos que les corresponden.</td></tr>
                        <tr><td><strong>Datos Sensibles</strong></td><td>Cifrado a nivel de columna, enmascaramiento dinámico de datos, hashing irreversible.</td><td>Protege la información más valiosa incluso si un atacante logra acceder a la tabla.</td></tr>
                        <tr><td><strong>Auditoría</strong></td><td>Logs detallados (pgaudit, Oracle Audit), integración con SIEM, alertas de anomalías.</td><td>Permite detectar actividades sospechosas en tiempo real y realizar análisis forenses tras un incidente.</td></tr>
                    </tbody>
                </table>
            </div>
        """
    },
    {
        "titulo": "3. Hashing: Fundamentos Criptográficos",
        "contenido": """
            <h4>Huellas Digitales Irreversibles</h4>
            <p>El hashing es una técnica de criptografía de un solo sentido fundamental para la seguridad de los datos.</p>
            <ul>
                <li><strong>Hash:</strong> Una función matemática que transforma una entrada de cualquier tamaño (ej. una contraseña) en una cadena de salida de longitud fija (la "huella" o "digest"). Debe ser <strong>determinista</strong> (la misma entrada siempre produce la misma salida) e <strong>irreversible</strong> (es computacionalmente inviable obtener la entrada original a partir de la salida).</li>
                <li><strong>Colisión:</strong> Ocurre cuando dos entradas diferentes producen el mismo hash. Un algoritmo de hash seguro debe tener una resistencia a colisiones extremadamente alta.</li>
                <li><strong>Sal (Salt):</strong> Un valor aleatorio único que se genera para cada usuario y se concatena con la contraseña <strong>antes</strong> de aplicar el hash. Su propósito es derrotar los ataques de <strong>tablas arcoíris (rainbow tables)</strong>, que son diccionarios de hashes precalculados.</li>
                <li><strong>Pimienta (Pepper):</strong> Un secreto del lado del servidor, constante para todos los usuarios, que se añade al proceso de hashing. A diferencia de la sal (que se almacena en la BD), la pimienta se gestiona fuera (ej. en un Key Management Service - KMS), añadiendo una capa de protección si la base de datos es comprometida.</li>
            </ul>
            <blockquote>Regla de oro: <strong>Nunca, bajo ninguna circunstancia, almacenes contraseñas en texto plano.</strong> Usa siempre un algoritmo de hash fuerte, con una sal única por usuario y, preferiblemente, una pimienta gestionada de forma segura.</blockquote>
        """
    },
    {
        "titulo": "4. Funciones Hash Nativas en SQL",
        "contenido": """
            <h4>Herramientas Integradas en los Motores de BD</h4>
            <p>La mayoría de los motores modernos proporcionan funciones para realizar hashing, aunque para contraseñas se recomiendan extensiones especializadas.</p>
             <div class="table-container">
                <table>
                    <thead><tr><th>Motor</th><th>Funciones Recomendadas</th><th>Notas de Uso</th></tr></thead>
                    <tbody>
                        <tr><td><strong>PostgreSQL</strong></td><td><code>digest(data, 'sha256')</code> (extensión <code>pgcrypto</code>)</td><td>Requiere instalar la extensión: <code>CREATE EXTENSION IF NOT EXISTS pgcrypto;</code>.</td></tr>
                        <tr><td><strong>MySQL 8+</strong></td><td><code>SHA2(str, 256)</code></td><td>Devuelve el hash como una cadena hexadecimal.</td></tr>
                        <tr><td><strong>SQL Server</strong></td><td><code>HASHBYTES('SHA2_512', @variable)</code></td><td>Disponible desde SQL Server 2016. La entrada está limitada a 8000 bytes.</td></tr>
                        <tr><td><strong>Oracle</strong></td><td><code>DBMS_CRYPTO.HASH(src_data, hash_type)</code></td><td>El tipo se especifica con una constante, ej. <code>DBMS_CRYPTO.HASH_SH512</code>.</td></tr>
                    </tbody>
                </table>
            </div>
        """
    },
    {
        "titulo": "5. Ejemplos Prácticos de Hashing",
        "contenido": """
            <h4>5.1. Almacenar Contraseñas de Forma Segura (PostgreSQL)</h4>
            <p>Este es el flujo correcto para registrar un nuevo usuario, creando una sal única y hasheando la contraseña.</p>
            <div class="content-block" style="background-color: #2d2d2d; color: #f0f0f0; font-family: 'JetBrains Mono', monospace; padding: 1rem; border-radius: 8px;">
<pre><code>-- Prerrequisito: CREATE EXTENSION IF NOT EXISTS pgcrypto;

-- Crear una tabla de usuarios segura
CREATE TABLE usuarios (
    id        BIGSERIAL PRIMARY KEY,
    username  TEXT NOT NULL UNIQUE,
    salt      BYTEA NOT NULL, -- La sal se almacena en formato binario
    pwd_hash  BYTEA NOT NULL  -- El hash también es binario
);

-- Insertar un nuevo usuario
WITH input AS (
  SELECT
    'super_segura_123'::bytea AS raw_password, -- Contraseña en texto plano (solo en memoria)
    gen_random_bytes(16)      AS salt          -- Generar 16 bytes de sal aleatoria
)
INSERT INTO usuarios (username, salt, pwd_hash)
SELECT
  'alice',
  input.salt,
  -- Concatenar contraseña y sal, y luego aplicar el hash SHA-256
  digest(input.raw_password || input.salt, 'sha256')
FROM input;</code></pre>
            </div>

            <h4>5.2. Validar Credenciales Durante el Login</h4>
            <p>Para verificar una contraseña, se recupera la sal del usuario y se repite el proceso de hashing con la contraseña proporcionada.</p>
             <div class="content-block" style="background-color: #2d2d2d; color: #f0f0f0; font-family: 'JetBrains Mono', monospace; padding: 1rem; border-radius: 8px;">
<pre><code>-- :username y :password son placeholders de una sentencia preparada
SELECT id
FROM usuarios
WHERE
  username = :username -- Buscar al usuario por su nombre
  AND pwd_hash = digest(:password::bytea || salt, 'sha256');
</code></pre>
            </div>
            <p>Si la consulta devuelve una fila, la contraseña es correcta. Si no devuelve nada, es incorrecta. El sistema nunca ve ni compara contraseñas en texto plano.</p>

            <h4>5.3. Garantizar la Integridad de Datos con Triggers</h4>
            <p>Se puede usar un hash como una "firma" para asegurar que un registro no ha sido alterado por fuera de la lógica de la aplicación.</p>
             <div class="content-block" style="background-color: #2d2d2d; color: #f0f0f0; font-family: 'JetBrains Mono', monospace; padding: 1rem; border-radius: 8px;">
<pre><code>-- Función que se ejecutará antes de cada INSERT o UPDATE
CREATE OR REPLACE FUNCTION calcular_firma_transaccion()
RETURNS TRIGGER AS $$
BEGIN
  -- Concatenar los campos críticos del registro y calcular su hash
  -- El registro a ser insertado/actualizado está en la variable especial "NEW"
  NEW.firma := digest(
      NEW.monto::text || NEW.moneda || NEW.id_cliente::text,
      'sha512'
  );
  RETURN NEW; -- Devolver el registro modificado para que se inserte
END;
$$ LANGUAGE plpgsql;

-- Asociar la función a la tabla "transacciones"
CREATE TRIGGER trg_firma_transacciones
BEFORE INSERT OR UPDATE ON transacciones
FOR EACH ROW EXECUTE FUNCTION calcular_firma_transaccion();</code></pre>
             </div>
        """
    },
    {
        "titulo": "6. Técnicas Avanzadas y Algoritmos Recomendados",
        "contenido": """
            <h4>Más Allá de SHA-256: Hashing Adaptativo</h4>
            <p>Para contraseñas, un hash rápido como SHA-256 no es suficiente. Los atacantes pueden probar miles de millones de hashes por segundo con hardware especializado (GPUs, ASICs). La solución es usar <strong>algoritmos de derivación de claves (KDFs)</strong> diseñados para ser lentos y costosos.</p>
            <ul>
                <li><strong>Argon2:</strong> <strong>(Recomendación actual)</strong> Ganador de la Password Hashing Competition. Es un algoritmo "memory-hard", lo que significa que su cómputo requiere una cantidad significativa de memoria, haciéndolo muy resistente a ataques con GPU.</li>
                <li><strong>bcrypt:</strong> Un estándar de la industria durante muchos años. Su "factor de coste" permite hacerlo más lento a medida que el hardware mejora.</li>
                <li><strong>PBKDF2:</strong> Otro estándar robusto, aunque generalmente se considera menos resistente que bcrypt y Argon2 contra hardware especializado.</li>
            </ul>
            <blockquote>Estos algoritmos se suelen implementar a nivel de aplicación (ej. en Python, Java, C#) o mediante extensiones de la base de datos (como <code>pg-sodium</code> para PostgreSQL, que soporta Argon2).</blockquote>

            <h4>HMAC: Hash para Autenticación de Mensajes</h4>
            <p>Un <strong>HMAC (Hash-based Message Authentication Code)</strong> es un tipo de hash que utiliza una clave secreta. Sirve para verificar tanto la <strong>integridad</strong> de los datos como la <strong>autenticidad</strong> del remitente. Es comúnmente usado en la generación de tokens (ej. JWT) y en la validación de webhooks.</p>
        """
    },
    {
        "titulo": "7. Prácticas Operativas de Seguridad (SecOps)",
        "contenido": """
            <h4>La Seguridad como Cultura, no solo como Código</h4>
            <ul>
                <li><strong>Gestión de Secretos:</strong> NUNCA guardes claves, contraseñas de BD o "peppers" en el código fuente o en variables de entorno sin cifrar. Utiliza un servicio especializado como <strong>HashiCorp Vault</strong>, <strong>AWS Secrets Manager</strong> o <strong>Azure Key Vault</strong>.</li>
                <li><strong>Migración de Hashes:</strong> Si necesitas actualizar de un algoritmo de hash antiguo (ej. MD5) a uno nuevo (Argon2), planifica una migración progresiva. Cuando un usuario inicie sesión con su contraseña antigua, verifica el hash antiguo, y si es correcto, crea un nuevo hash con el algoritmo moderno y actualiza su registro.</li>
                <li><strong>Auditoría de Permisos:</strong> Realiza auditorías periódicas para encontrar y revocar permisos innecesarios o roles de usuario inactivos.</li>
                <li><strong>Automatización de Pruebas:</strong> Integra herramientas de análisis de seguridad estático (SAST) y dinámico (DAST) en tu pipeline de CI/CD para detectar vulnerabilidades como la inyección SQL antes de que lleguen a producción.</li>
            </ul>
        """
    }
]


# --- LÓGICA DE GENERACIÓN (SIN CAMBIOS) ---
def generar_tarjetas_definiciones(datos):
    html_generado = []
    for seccion in datos:
        titulo_escapado = html.escape(seccion['titulo'])
        contenido_html = seccion['contenido']
        plantilla_seccion = f"""
        <div class="topic-card">
            <div class="topic-header">
                <span class="topic-title">{titulo_escapado}</span>
                <i class="fas fa-chevron-down expand-icon"></i>
            </div>
            <div class="topic-content">
                {contenido_html}
            </div>
        </div>
        """
        html_generado.append(plantilla_seccion)
    return "\n".join(html_generado)

# --- PRE-CÁLCULO DEL CONTENIDO DINÁMICO ---
contenido_dinamico_html = generar_tarjetas_definiciones(security_concepts_data)

# --- PLANTILLA PROFESIONAL (SIN CAMBIOS) ---
plantilla_profesional = """
<!DOCTYPE html>
<html lang="es">
<head>
  <meta charset="UTF-8">
  <meta name="viewport" content="width=device-width, initial-scale=1.0">
  <title>{main_title}</title>
  <link href="https://fonts.googleapis.com/css2?family=Inter:wght@300;400;500;600;700;800&family=JetBrains+Mono:wght@400;500&display=swap" rel="stylesheet">
  <link href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.4.0/css/all.min.css" rel="stylesheet">
  <style>
    :root {{
      --bg-primary: linear-gradient(135deg, #0f2027 0%, #203a43 50%, #2c5364 100%);
      --bg-secondary: rgba(26, 32, 44, 0.85);
      --bg-tertiary: rgba(45, 55, 72, 0.7);
      --text-primary: #f7fafc;
      --text-secondary: #a0aec0;
      --accent-primary: #e67e22;
      --accent-secondary: #d35400;
      --accent-gradient: linear-gradient(135deg, var(--accent-primary) 0%, var(--accent-secondary) 100%);
      --border-color: rgba(255, 255, 255, 0.15);
      --shadow-card: 0 15px 35px rgba(0, 0, 0, 0.1);
      --border-radius: 20px;
      --transition: all 0.4s cubic-bezier(0.25, 0.8, 0.25, 1);
    }}
    [data-theme="light"] {{
      --bg-primary: linear-gradient(135deg, #f5f7fa 0%, #c3cfe2 100%);
      --bg-secondary: rgba(255, 255, 255, 0.85);
      --bg-tertiary: rgba(248, 250, 252, 0.8);
      --text-primary: #2c3e50;
      --text-secondary: #34495e;
      --accent-primary: #e74c3c;
      --accent-secondary: #c0392b;
      --border-color: rgba(226, 232, 240, 0.8);
    }}
    * {{ margin: 0; padding: 0; box-sizing: border-box; }}
    html {{ scroll-behavior: smooth; }}
    body {{ font-family: 'Inter', sans-serif; line-height: 1.8; background: var(--bg-primary); color: var(--text-primary); transition: var(--transition); min-height: 100vh; position: relative; overflow-x: hidden; }}
    .particles {{ position: fixed; top: 0; left: 0; width: 100%; height: 100%; pointer-events: none; z-index: -1; }}
    .particle {{ position: absolute; border-radius: 50%; animation: float 25s infinite linear; opacity: 0; background: rgba(255, 255, 255, 0.6);}}
    @keyframes float {{ 0% {{ transform: translateY(100vh) rotate(0deg); opacity: 0; }} 10%, 90% {{ opacity: 0.6; }} 100% {{ transform: translateY(-10vh) rotate(360deg); opacity: 0; }} }}

    .container {{ max-width: 1000px; margin: 0 auto; padding: 2rem; z-index: 1; }}
    .header {{ text-align: center; margin-bottom: 3rem; position: relative; }}
    .main-title {{ font-size: clamp(2.2rem, 5vw, 3.8rem); font-weight: 800; background: var(--accent-gradient); -webkit-background-clip: text; -webkit-text-fill-color: transparent; background-clip: text; margin-bottom: 1rem; }}

    .theme-toggle {{ position: fixed; top: 2rem; right: 2rem; width: 60px; height: 60px; border: 1px solid var(--border-color); border-radius: 50%; background: var(--bg-secondary); backdrop-filter: blur(15px); box-shadow: var(--shadow-card); cursor: pointer; display: flex; align-items: center; justify-content: center; font-size: 1.4rem; color: var(--accent-primary); transition: var(--transition); z-index: 1000; }}
    .theme-toggle:hover {{ transform: scale(1.15) rotate(180deg); }}

    .content-block {{
        background: var(--bg-secondary); backdrop-filter: blur(20px); border-radius: var(--border-radius);
        box-shadow: var(--shadow-card); border: 2px solid var(--border-color);
        padding: 2rem; margin-bottom: 2rem;
    }}
    .content-block h2 {{ color: var(--text-primary); margin-bottom: 1rem; }}
    .content-block p, .content-block li {{ color: var(--text-secondary); margin-bottom: 1rem; }}
    .content-block ul {{padding-left: 20px;}}

    .lesson-container {{ display: flex; flex-direction: column; gap: 1.5rem; }}
    .topic-card {{ background: var(--bg-secondary); backdrop-filter: blur(20px); border-radius: var(--border-radius); box-shadow: var(--shadow-card); border: 2px solid var(--border-color); overflow: hidden; transition: var(--transition); }}
    .topic-header {{ cursor: pointer; padding: 1.5rem 2rem; display: flex; justify-content: space-between; align-items: center; }}
    .topic-title {{ font-size: 1.3rem; font-weight: 600; color: var(--text-primary); }}
    .expand-icon {{ font-size: 1.2rem; color: var(--text-secondary); transition: var(--transition); }}
    .topic-card.open .expand-icon {{ transform: rotate(180deg); color: var(--accent-primary); }}
    .topic-content {{ max-height: 0; overflow: hidden; transition: max-height 1.8s ease, padding 1.8s ease; background: var(--bg-tertiary); }}
    .topic-card.open .topic-content {{ max-height: 5500px; padding: 1.5rem 2rem; border-top: 1px solid var(--border-color); }}

    .topic-content h4 {{ color: var(--text-primary); margin-top: 1.5rem; margin-bottom: 0.5rem; font-size: 1.1rem; }}
    .topic-content p, .topic-content li {{ color: var(--text-secondary); line-height: 1.7; }}
    .topic-content ul {{ padding-left: 25px; margin-bottom: 1rem; }}
    .topic-content strong {{ color: var(--accent-primary); font-weight: 700; }}
    .topic-content blockquote {{
        border-left: 4px solid var(--accent-primary); padding-left: 1.5rem; margin: 1.5rem 0;
        font-style: italic; color: var(--text-secondary); background: rgba(127, 140, 141, 0.05);
        border-radius: 0 8px 8px 0; padding: 1rem 1.5rem;
    }}
    .table-container {{ overflow-x: auto; margin: 1.5rem 0; }}
    table {{ width: 100%; border-collapse: collapse; }}
    th, td {{ padding: 12px 15px; border: 1px solid var(--border-color); text-align: left; }}
    thead th {{ background-color: var(--bg-tertiary); color: var(--text-primary); font-weight: 600; }}
    tbody tr:nth-child(even) {{ background: rgba(127, 140, 141, 0.05); }}

    footer {{ text-align: center; margin-top: 4rem; padding-top: 2rem; border-top: 1px solid var(--border-color); }}
    footer p {{ color: var(--text-secondary); font-size: 0.9rem; opacity: 0.8; }}
  </style>
</head>
<body data-theme="dark">
  <div class="particles" id="particles-container"></div>
  <div class="theme-toggle" id="themeToggleButton" title="Cambiar tema"><i class="fas fa-moon" id="theme-icon"></i></div>
  <div class="container">
    <header class="header">
      <h1 class="main-title">{main_title}</h1>
    </header>
    <div class="lesson-container">
        {dynamic_content_html}
    </div>
    {conclusion_html}
    <footer>
      <p>{footer_text}</p>
    </footer>
  </div>
  <script>
    (function() {{
        const themeToggleButton = document.getElementById('themeToggleButton');
        const themeIcon = document.getElementById('theme-icon');
        const bodyEl = document.body;
        function setTheme(theme) {{
            bodyEl.setAttribute('data-theme', theme);
            localStorage.setItem('theme', theme);
            if (themeIcon) {{ themeIcon.className = theme === 'dark' ? 'fas fa-sun' : 'fas fa-moon'; }}
        }}
        themeToggleButton.addEventListener('click', () => {{
            const newTheme = (bodyEl.getAttribute('data-theme') || 'dark') === 'light' ? 'light' : 'dark';
            setTheme(newTheme);
        }});
        setTheme(localStorage.getItem('theme') || 'dark');
        document.querySelectorAll('.topic-header').forEach(header => {{
            header.addEventListener('click', () => {{
                header.parentElement.classList.toggle('open');
            }});
        }});
        const container = document.getElementById('particles-container');
        if (container) {{ for (let i = 0; i < 30; i++) {{ const p = document.createElement('div'); p.className = 'particle'; p.style.left = Math.random() * 100 + 'vw'; const size = (Math.random() * 5 + 2); p.style.width = size + 'px'; p.style.height = size + 'px'; p.style.animationDelay = Math.random() * -20 + 's'; p.style.animationDuration = (15 + Math.random() * 10) + 's'; container.appendChild(p); }} }}
        const firstTopic = document.querySelector('.topic-card');
        if(firstTopic) {{ firstTopic.classList.add('open'); }}
    }})();
  </script>
</body>
</html>
"""

# --- INYECCIÓN DINÁMICA Y RENDERIZADO FINAL ---
final_html = plantilla_profesional.format(
    main_title="Seguridad SQL y Hashing: Guía de Hardening",
    dynamic_content_html=contenido_dinamico_html,
    conclusion_html=conclusion_html_block,
    footer_text="Elaborado por profesor Sergio Gevatschnaider"
)

display(HTML(final_html))
# Out:
# <!DOCTYPE html>
# <html lang="es">
# <head>
#   <meta charset="UTF-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1.0">
#   <title>Seguridad SQL y Hashing: Guía de Hardening</title>
#   <link href="https://fonts.googleapis.com/css2?family=Inter:wght@300;400;500;600;700;800&family=JetBrains+Mono:wght@400;500&display=swap" rel="stylesheet">
#   <link href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.4.0/css/all.min.css" rel="stylesheet">
#   <style>
#     :root {
#       --bg-primary: linear-gradient(135deg, #0f2027 0%, #203a43 50%, #2c5364 100%);
#       --bg-secondary: rgba(26, 32, 44, 0.85);
#       --bg-tertiary: rgba(45, 55, 72, 0.7);
#       --text-primary: #f7fafc;
#       --text-secondary: #a0aec0;
#       --accent-primary: #e67e22;
#       --accent-secondary: #d35400;
#       --accent-gradient: linear-gradient(135deg, var(--accent-primary) 0%, var(--accent-secondary) 100%);
#       --border-color: rgba(255, 255, 255, 0.15);
# ...
